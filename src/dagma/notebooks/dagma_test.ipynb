# %%
import os
path = '/Users/jiahang/Documents/dagma/src/dagma/'
os.chdir(path)

# %%
import utils_dagma
import linear

from importlib import reload
reload(utils_dagma)
reload(linear)
# Out:
# <module 'linear' from '/Users/jiahang/Documents/dagma/src/dagma/linear.py'>

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 60, 240
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2') # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'nnz': 240}

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 60, 600
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2') # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# {'fdr': 0.2717391304347826, 'tpr': 0.8933333333333333, 'fpr': 0.17094017094017094, 'shd': 256, 'nnz': 736}

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 60, 1000
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2') # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# {'fdr': 0.44192634560906513, 'tpr': 0.394, 'fpr': 0.4051948051948052, 'shd': 918, 'nnz': 706}

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 20, 100
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2') # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# {'fdr': 0.07142857142857142, 'tpr': 0.91, 'fpr': 0.07777777777777778, 'shd': 13, 'nnz': 98}

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 60, 1000
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2', verbose=True) # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# Iteration -- 1:
#
#
# Minimize with -- mu:1.0 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 1.5906e-01
# 	score(W_est): 1.8052e+16
# 	obj(W_est): 1.8052e+16
#
# Inner iteration 2000
# 	h(W_est): 2.2328e-01
# 	score(W_est): 1.6555e+12
# 	obj(W_est): 1.6555e+12
#
# Inner iteration 3000
# 	h(W_est): 2.2372e-01
# 	score(W_est): 1.9716e+10
# 	obj(W_est): 1.9716e+10
#
# Inner iteration 4000
# 	h(W_est): 2.2390e-01
# 	score(W_est): 1.9543e+10
# 	obj(W_est): 1.9543e+10
#
# Inner iteration 5000
# 	h(W_est): 2.2439e-01
# 	score(W_est): 1.9525e+10
# 	obj(W_est): 1.9525e+10
#
# Inner iteration 6000
# 	h(W_est): 2.2568e-01
# 	score(W_est): 1.9495e+10
# 	obj(W_est): 1.9495e+10
#
# Inner iteration 7000
# 	h(W_est): 2.2884e-01
# 	score(W_est): 1.9451e+10
# 	obj(W_est): 1.9451e+10
#
# Inner iteration 8000
# 	h(W_est): 2.3575e-01
# 	score(W_est): 1.9431e+10
# 	obj(W_est): 1.9431e+10
#
# Inner iteration 9000
# 	h(W_est): 2.4286e-01
# 	score(W_est): 1.9312e+10
# 	obj(W_est): 1.9312e+10
#
# Inner iteration 10000
# 	h(W_est): 2.5091e-01
# 	score(W_est): 1.9217e+10
# 	obj(W_est): 1.9217e+10
#
# Inner iteration 11000
# 	h(W_est): 2.5992e-01
# 	score(W_est): 1.9061e+10
# 	obj(W_est): 1.9061e+10
#
# Inner iteration 12000
# 	h(W_est): 2.6903e-01
# 	score(W_est): 1.8917e+10
# 	obj(W_est): 1.8917e+10
#
# Inner iteration 13000
# 	h(W_est): 2.7703e-01
# 	score(W_est): 1.8699e+10
# 	obj(W_est): 1.8699e+10
#
# Inner iteration 14000
# 	h(W_est): 2.8402e-01
# 	score(W_est): 1.8348e+10
# 	obj(W_est): 1.8348e+10
#
# Inner iteration 15000
# 	h(W_est): 2.9007e-01
# 	score(W_est): 1.7927e+10
# 	obj(W_est): 1.7927e+10
#
# Inner iteration 16000
# 	h(W_est): 2.9529e-01
# 	score(W_est): 1.7428e+10
# 	obj(W_est): 1.7428e+10
#
# Inner iteration 17000
# 	h(W_est): 2.9998e-01
# 	score(W_est): 1.6814e+10
# 	obj(W_est): 1.6814e+10
#
# Inner iteration 18000
# 	h(W_est): 3.0441e-01
# 	score(W_est): 1.6041e+10
# 	obj(W_est): 1.6041e+10
#
# Inner iteration 19000
# 	h(W_est): 3.0837e-01
# 	score(W_est): 1.5242e+10
# 	obj(W_est): 1.5242e+10
# Learning rate decreased to lr: 0.00015
# Learning rate decreased to lr: 7.5e-05
# Learning rate decreased to lr: 3.75e-05
# Learning rate decreased to lr: 1.875e-05
# Learning rate decreased to lr: 9.375e-06
# Learning rate decreased to lr: 4.6875e-06
# Learning rate decreased to lr: 2.34375e-06
# Learning rate decreased to lr: 1.171875e-06
# Learning rate decreased to lr: 5.859375e-07
# Learning rate decreased to lr: 2.9296875e-07
# Learning rate decreased to lr: 1.46484375e-07
# Learning rate decreased to lr: 7.32421875e-08
# Learning rate decreased to lr: 3.662109375e-08
# Learning rate decreased to lr: 1.8310546875e-08
# Learning rate decreased to lr: 9.1552734375e-09
# Learning rate decreased to lr: 4.57763671875e-09
# Learning rate decreased to lr: 2.288818359375e-09
# Learning rate decreased to lr: 1.1444091796875e-09
# Learning rate decreased to lr: 5.7220458984375e-10
# Learning rate decreased to lr: 2.86102294921875e-10
# Learning rate decreased to lr: 1.430511474609375e-10
# Learning rate decreased to lr: 7.152557373046874e-11
# Learning rate decreased to lr: 3.576278686523437e-11
# Learning rate decreased to lr: 1.7881393432617186e-11
# Learning rate decreased to lr: 8.940696716308593e-12
# Learning rate decreased to lr: 4.4703483581542965e-12
# Learning rate decreased to lr: 2.2351741790771482e-12
# Learning rate decreased to lr: 1.1175870895385741e-12
# Learning rate decreased to lr: 5.587935447692871e-13
# Learning rate decreased to lr: 2.7939677238464353e-13
# Learning rate decreased to lr: 1.3969838619232177e-13
# Learning rate decreased to lr: 6.984919309616088e-14
# Learning rate decreased to lr: 3.492459654808044e-14
# Learning rate decreased to lr: 1.746229827404022e-14
# Learning rate decreased to lr: 8.73114913702011e-15
# Learning rate decreased to lr: 4.365574568510055e-15
# Learning rate decreased to lr: 2.1827872842550276e-15
# Learning rate decreased to lr: 1.0913936421275138e-15
# Learning rate decreased to lr: 5.456968210637569e-16
# Learning rate decreased to lr: 2.7284841053187845e-16
# Learning rate decreased to lr: 1.3642420526593922e-16
#
# Iteration -- 2:
#
#
# Minimize with -- mu:0.1 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 3.0981e-01
# 	score(W_est): 1.5015e+10
# 	obj(W_est): 1.5015e+09
# Learning rate decreased to lr: 0.00015
# Learning rate decreased to lr: 7.5e-05
# Learning rate decreased to lr: 3.75e-05
# Learning rate decreased to lr: 1.875e-05
# Learning rate decreased to lr: 9.375e-06
# Learning rate decreased to lr: 4.6875e-06
# Learning rate decreased to lr: 2.34375e-06
# Learning rate decreased to lr: 1.171875e-06
# Learning rate decreased to lr: 5.859375e-07
# Learning rate decreased to lr: 2.9296875e-07
# Learning rate decreased to lr: 1.46484375e-07
# Learning rate decreased to lr: 7.32421875e-08
# Learning rate decreased to lr: 3.662109375e-08
# Learning rate decreased to lr: 1.8310546875e-08
# Learning rate decreased to lr: 9.1552734375e-09
# Learning rate decreased to lr: 4.57763671875e-09
# Learning rate decreased to lr: 2.288818359375e-09
# Learning rate decreased to lr: 1.1444091796875e-09
# Learning rate decreased to lr: 5.7220458984375e-10
# Learning rate decreased to lr: 2.86102294921875e-10
# Learning rate decreased to lr: 1.430511474609375e-10
# Learning rate decreased to lr: 7.152557373046874e-11
# Learning rate decreased to lr: 3.576278686523437e-11
# Learning rate decreased to lr: 1.7881393432617186e-11
# Learning rate decreased to lr: 8.940696716308593e-12
# Learning rate decreased to lr: 4.4703483581542965e-12
# Learning rate decreased to lr: 2.2351741790771482e-12
# Learning rate decreased to lr: 1.1175870895385741e-12
# Learning rate decreased to lr: 5.587935447692871e-13
# Learning rate decreased to lr: 2.7939677238464353e-13
# Learning rate decreased to lr: 1.3969838619232177e-13
# Learning rate decreased to lr: 6.984919309616088e-14
# Learning rate decreased to lr: 3.492459654808044e-14
# Learning rate decreased to lr: 1.746229827404022e-14
# Learning rate decreased to lr: 8.73114913702011e-15
# Learning rate decreased to lr: 4.365574568510055e-15
# Learning rate decreased to lr: 2.1827872842550276e-15
# Learning rate decreased to lr: 1.0913936421275138e-15
# Learning rate decreased to lr: 5.456968210637569e-16
# Learning rate decreased to lr: 2.7284841053187845e-16
# Learning rate decreased to lr: 1.3642420526593922e-16
#
# Iteration -- 3:
#
#
# Minimize with -- mu:0.010000000000000002 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 3.0991e-01
# 	score(W_est): 1.4904e+10
# 	obj(W_est): 1.4904e+08
# Learning rate decreased to lr: 0.00015
# Learning rate decreased to lr: 7.5e-05
# Learning rate decreased to lr: 3.75e-05
# Learning rate decreased to lr: 1.875e-05
# Learning rate decreased to lr: 9.375e-06
# Learning rate decreased to lr: 4.6875e-06
# Learning rate decreased to lr: 2.34375e-06
# Learning rate decreased to lr: 1.171875e-06
# Learning rate decreased to lr: 5.859375e-07
# Learning rate decreased to lr: 2.9296875e-07
# Learning rate decreased to lr: 1.46484375e-07
# Learning rate decreased to lr: 7.32421875e-08
# Learning rate decreased to lr: 3.662109375e-08
# Learning rate decreased to lr: 1.8310546875e-08
# Learning rate decreased to lr: 9.1552734375e-09
# Learning rate decreased to lr: 4.57763671875e-09
# Learning rate decreased to lr: 2.288818359375e-09
# Learning rate decreased to lr: 1.1444091796875e-09
# Learning rate decreased to lr: 5.7220458984375e-10
# Learning rate decreased to lr: 2.86102294921875e-10
# Learning rate decreased to lr: 1.430511474609375e-10
# Learning rate decreased to lr: 7.152557373046874e-11
# Learning rate decreased to lr: 3.576278686523437e-11
# Learning rate decreased to lr: 1.7881393432617186e-11
# Learning rate decreased to lr: 8.940696716308593e-12
# Learning rate decreased to lr: 4.4703483581542965e-12
# Learning rate decreased to lr: 2.2351741790771482e-12
# Learning rate decreased to lr: 1.1175870895385741e-12
# Learning rate decreased to lr: 5.587935447692871e-13
# Learning rate decreased to lr: 2.7939677238464353e-13
# Learning rate decreased to lr: 1.3969838619232177e-13
# Learning rate decreased to lr: 6.984919309616088e-14
# Learning rate decreased to lr: 3.492459654808044e-14
# Learning rate decreased to lr: 1.746229827404022e-14
# Learning rate decreased to lr: 8.73114913702011e-15
# Learning rate decreased to lr: 4.365574568510055e-15
# Learning rate decreased to lr: 2.1827872842550276e-15
# Learning rate decreased to lr: 1.0913936421275138e-15
# Learning rate decreased to lr: 5.456968210637569e-16
# Learning rate decreased to lr: 2.7284841053187845e-16
# Learning rate decreased to lr: 1.3642420526593922e-16
#
# Iteration -- 4:
#
#
# Minimize with -- mu:0.0010000000000000002 -- lr: 0.0003 -- s: 1.0999999999999999 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 2.7950e-01
# 	score(W_est): 1.4695e+10
# 	obj(W_est): 1.4695e+07
# Learning rate decreased to lr: 0.00015
# Learning rate decreased to lr: 7.5e-05
# Learning rate decreased to lr: 3.75e-05
# Learning rate decreased to lr: 1.875e-05
# Learning rate decreased to lr: 9.375e-06
# Learning rate decreased to lr: 4.6875e-06
# Learning rate decreased to lr: 2.34375e-06
# Learning rate decreased to lr: 1.171875e-06
# Learning rate decreased to lr: 5.859375e-07
# Learning rate decreased to lr: 2.9296875e-07
# Learning rate decreased to lr: 1.46484375e-07
# Learning rate decreased to lr: 7.32421875e-08
#
# Inner iteration 2000
# 	h(W_est): 2.7920e-01
# 	score(W_est): 1.4193e+10
# 	obj(W_est): 1.4193e+07
# Learning rate decreased to lr: 3.662109375e-08
# Learning rate decreased to lr: 1.8310546875e-08
# Learning rate decreased to lr: 9.1552734375e-09
# Learning rate decreased to lr: 4.57763671875e-09
# Learning rate decreased to lr: 2.288818359375e-09
# Learning rate decreased to lr: 1.1444091796875e-09
# Learning rate decreased to lr: 5.7220458984375e-10
# Learning rate decreased to lr: 2.86102294921875e-10
# Learning rate decreased to lr: 1.430511474609375e-10
# Learning rate decreased to lr: 7.152557373046874e-11
# Learning rate decreased to lr: 3.576278686523437e-11
# Learning rate decreased to lr: 1.7881393432617186e-11
# Learning rate decreased to lr: 8.940696716308593e-12
# Learning rate decreased to lr: 4.4703483581542965e-12
# Learning rate decreased to lr: 2.2351741790771482e-12
# Learning rate decreased to lr: 1.1175870895385741e-12
# Learning rate decreased to lr: 5.587935447692871e-13
# Learning rate decreased to lr: 2.7939677238464353e-13
# Learning rate decreased to lr: 1.3969838619232177e-13
# Learning rate decreased to lr: 6.984919309616088e-14
# Learning rate decreased to lr: 3.492459654808044e-14
# Learning rate decreased to lr: 1.746229827404022e-14
# Learning rate decreased to lr: 8.73114913702011e-15
# Learning rate decreased to lr: 4.365574568510055e-15
# Learning rate decreased to lr: 2.1827872842550276e-15
# Learning rate decreased to lr: 1.0913936421275138e-15
# Learning rate decreased to lr: 5.456968210637569e-16
# Learning rate decreased to lr: 2.7284841053187845e-16
# Learning rate decreased to lr: 1.3642420526593922e-16
#
# Iteration -- 5:
#
#
# Minimize with -- mu:0.00010000000000000003 -- lr: 0.0003 -- s: 0.9999999999999999 -- l1: 0.02 for 60000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 3.0770e-01
# 	score(W_est): 1.4270e+10
# 	obj(W_est): 1.4270e+06
#
# Inner iteration 2000
# 	h(W_est): 3.0406e-01
# 	score(W_est): 1.3619e+10
# 	obj(W_est): 1.3619e+06
# Learning rate decreased to lr: 0.00015
# Learning rate decreased to lr: 7.5e-05
#
# Inner iteration 3000
# 	h(W_est): 3.0243e-01
# 	score(W_est): 1.3294e+10
# 	obj(W_est): 1.3294e+06
# Learning rate decreased to lr: 3.75e-05
# Learning rate decreased to lr: 1.875e-05
# Learning rate decreased to lr: 9.375e-06
# Learning rate decreased to lr: 4.6875e-06
#
# Inner iteration 4000
# 	h(W_est): 3.0231e-01
# 	score(W_est): 1.3252e+10
# 	obj(W_est): 1.3252e+06
# Learning rate decreased to lr: 2.34375e-06
#
# Inner iteration 5000
# 	h(W_est): 3.0226e-01
# 	score(W_est): 1.3236e+10
# 	obj(W_est): 1.3236e+06
# Learning rate decreased to lr: 1.171875e-06
# Learning rate decreased to lr: 5.859375e-07
# Learning rate decreased to lr: 2.9296875e-07
#
# Inner iteration 6000
# 	h(W_est): 3.0225e-01
# 	score(W_est): 1.3230e+10
# 	obj(W_est): 1.3230e+06
# Learning rate decreased to lr: 1.46484375e-07
# Learning rate decreased to lr: 7.32421875e-08
# Learning rate decreased to lr: 3.662109375e-08
#
# Inner iteration 7000
# 	h(W_est): 3.0224e-01
# 	score(W_est): 1.3229e+10
# 	obj(W_est): 1.3229e+06
# Learning rate decreased to lr: 1.8310546875e-08
# Learning rate decreased to lr: 9.1552734375e-09
# Learning rate decreased to lr: 4.57763671875e-09
# Learning rate decreased to lr: 2.288818359375e-09
#
# Inner iteration 8000
# 	h(W_est): 3.0224e-01
# 	score(W_est): 1.3229e+10
# 	obj(W_est): 1.3229e+06
# Learning rate decreased to lr: 1.1444091796875e-09
# Learning rate decreased to lr: 5.7220458984375e-10
#
# Inner iteration 9000
# 	h(W_est): 3.0224e-01
# 	score(W_est): 1.3229e+10
# 	obj(W_est): 1.3229e+06
# Learning rate decreased to lr: 2.86102294921875e-10
# Learning rate decreased to lr: 1.430511474609375e-10
#
# Inner iteration 10000
# 	h(W_est): 3.0224e-01
# 	score(W_est): 1.3229e+10
# 	obj(W_est): 1.3229e+06
# {'fdr': 0.4390625, 'tpr': 0.359, 'fpr': 0.36493506493506495, 'shd': 922, 'nnz': 640}

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 80, 1000
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2') # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# {'fdr': 0.6428571428571429, 'tpr': 0.46, 'fpr': 0.38333333333333336, 'shd': 1368, 'nnz': 1288}

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 70, 500
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2') # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 12
#       9 X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)
#      11 model = linear.DagmaLinear(loss_type='l2') # create a linear model with least squares loss
# ---> 12 W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
#      13 acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
#      14 print(acc)
#
# File ~/Documents/dagma/src/dagma/linear.py:381, in DagmaLinear.fit(self, dagma_type, X, lambda1, w_threshold, T, mu_init, mu_factor, s, warm_iter, max_iter, lr, checkpoint, beta_1, beta_2, exclude_edges, include_edges, return_no_filter)
#     379 inner_iters = int(max_iter) if i == T - 1 else int(warm_iter)
#     380 while success is False:
# --> 381     W_temp, success = self.minimize(self.W_est.copy(), mu, inner_iters, s[i], lr=lr_adam, beta_1=beta_1, beta_2=beta_2, pbar=pbar)
#     382     if dagma_type == 'dagma_1':
#     383         W_temp = self.clean_diag(W_temp)
#
# File ~/Documents/dagma/src/dagma/linear.py:191, in DagmaLinear.minimize(self, W, mu, max_iter, s, lr, tol, beta_1, beta_2, pbar)
#     187         mask_exc[self.exc_r, self.exc_c] = 0.
#     189 for iter in range(1, max_iter+1):
#     190     ## Compute the (sub)gradient of the objective
# --> 191     M = sla.inv(s * self.Id - W * W) + 1e-16
#     192     while np.any(M < 0): # sI - W o W is not an M-matrix
#     193         if iter == 1 or s <= 0.9:
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/scipy/linalg/_basic.py:958, in inv(a, overwrite_a, check_finite)
#     951     # XXX: the following line fixes curious SEGFAULT when
#     952     # benchmarking 500x500 matrix inverse. This seems to
#     953     # be a bug in LAPACK ?getri routine because if lwork is
#     954     # minimal (when using lwork[0] instead of lwork[1]) then
#     955     # all tests pass. Further investigation is required if
#     956     # more such SEGFAULTs occur.
#     957     lwork = int(1.01 * lwork)
# --> 958     inv_a, info = getri(lu, piv, lwork=lwork, overwrite_lu=1)
#     959 if info > 0:
#     960     raise LinAlgError("singular matrix")
#
# KeyboardInterrupt:

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 200, 80, 320
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2') # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 12
#       9 X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)
#      11 model = linear.DagmaLinear(loss_type='l2') # create a linear model with least squares loss
# ---> 12 W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
#      13 acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
#      14 print(acc)
#
# File ~/Documents/dagma/src/dagma/linear.py:381, in DagmaLinear.fit(self, dagma_type, X, lambda1, w_threshold, T, mu_init, mu_factor, s, warm_iter, max_iter, lr, checkpoint, beta_1, beta_2, exclude_edges, include_edges, return_no_filter)
#     379 inner_iters = int(max_iter) if i == T - 1 else int(warm_iter)
#     380 while success is False:
# --> 381     W_temp, success = self.minimize(self.W_est.copy(), mu, inner_iters, s[i], lr=lr_adam, beta_1=beta_1, beta_2=beta_2, pbar=pbar)
#     382     if dagma_type == 'dagma_1':
#     383         W_temp = self.clean_diag(W_temp)
#
# File ~/Documents/dagma/src/dagma/linear.py:191, in DagmaLinear.minimize(self, W, mu, max_iter, s, lr, tol, beta_1, beta_2, pbar)
#     187         mask_exc[self.exc_r, self.exc_c] = 0.
#     189 for iter in range(1, max_iter+1):
#     190     ## Compute the (sub)gradient of the objective
# --> 191     M = sla.inv(s * self.Id - W * W) + 1e-16
#     192     while np.any(M < 0): # sI - W o W is not an M-matrix
#     193         if iter == 1 or s <= 0.9:
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/scipy/linalg/_basic.py:958, in inv(a, overwrite_a, check_finite)
#     951     # XXX: the following line fixes curious SEGFAULT when
#     952     # benchmarking 500x500 matrix inverse. This seems to
#     953     # be a bug in LAPACK ?getri routine because if lwork is
#     954     # minimal (when using lwork[0] instead of lwork[1]) then
#     955     # all tests pass. Further investigation is required if
#     956     # more such SEGFAULTs occur.
#     957     lwork = int(1.01 * lwork)
# --> 958     inv_a, info = getri(lu, piv, lwork=lwork, overwrite_lu=1)
#     959 if info > 0:
#     960     raise LinAlgError("singular matrix")
#
# KeyboardInterrupt:

# %%
import line_profiler
profile = line_profiler.LineProfiler()

@profile
def test():
    W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)

test()
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]

# %%
profile.print_stats()
# Out:
# Timer unit: 1e-09 s
#
# Total time: 9.07768 s
# File: /var/folders/_j/jhp4k00j0vx40wdvn_jv_jr40000gn/T/ipykernel_23326/2197405495.py
# Function: test at line 4
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      4                                           @profile
#      5                                           def test():
#      6         1 9077683000.0    9e+09    100.0      W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 160, 1000
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2') # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# {'fdr': 0.4828962371721779, 'tpr': 0.907, 'fpr': 0.07226962457337884, 'shd': 926, 'nnz': 1754}

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 160, 1000
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2', verbose=True) # create a linear model with least squares loss
W_est = model.fit('dagma_1', X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# Iteration -- 1:
#
#
# Minimize with -- mu:1.0 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 9.5727e-01
# 	score(W_est): 4.1876e+06
# 	obj(W_est): 4.1876e+06
#
# Inner iteration 2000
# 	h(W_est): 1.8446e+00
# 	score(W_est): 3.4069e+05
# 	obj(W_est): 3.4071e+05
#
# Inner iteration 3000
# 	h(W_est): 2.5176e+00
# 	score(W_est): 1.5985e+05
# 	obj(W_est): 1.5988e+05
#
# Inner iteration 4000
# 	h(W_est): 3.0507e+00
# 	score(W_est): 1.0379e+05
# 	obj(W_est): 1.0382e+05
#
# Inner iteration 5000
# 	h(W_est): 3.4570e+00
# 	score(W_est): 6.3748e+04
# 	obj(W_est): 6.3777e+04
#
# Inner iteration 6000
# 	h(W_est): 3.7463e+00
# 	score(W_est): 3.8165e+04
# 	obj(W_est): 3.8196e+04
#
# Inner iteration 7000
# 	h(W_est): 3.9290e+00
# 	score(W_est): 2.3061e+04
# 	obj(W_est): 2.3093e+04
#
# Inner iteration 8000
# 	h(W_est): 4.0599e+00
# 	score(W_est): 1.3720e+04
# 	obj(W_est): 1.3754e+04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 12
#       9 X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)
#      11 model = linear.DagmaLinear(loss_type='l2', verbose=True) # create a linear model with least squares loss
# ---> 12 W_est = model.fit('dagma_1', X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
#      13 acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
#      14 print(acc)
#
# File ~/Documents/dagma/src/dagma/linear.py:381, in DagmaLinear.fit(self, dagma_type, X, lambda1, w_threshold, T, mu_init, mu_factor, s, warm_iter, max_iter, lr, checkpoint, beta_1, beta_2, exclude_edges, include_edges, return_no_filter)
#     379 inner_iters = int(max_iter) if i == T - 1 else int(warm_iter)
#     380 while success is False:
# --> 381     W_temp, success = self.minimize(self.W_est.copy(), mu, inner_iters, s[i], lr=lr_adam, beta_1=beta_1, beta_2=beta_2, pbar=pbar)
#     382     if dagma_type == 'dagma_1':
#     383         W_temp = self.clean_diag(W_temp)
#
# File ~/Documents/dagma/src/dagma/linear.py:191, in DagmaLinear.minimize(self, W, mu, max_iter, s, lr, tol, beta_1, beta_2, pbar)
#     187         mask_exc[self.exc_r, self.exc_c] = 0.
#     189 for iter in range(1, max_iter+1):
#     190     ## Compute the (sub)gradient of the objective
# --> 191     M = sla.inv(s * self.Id - W * W) + 1e-16
#     192     while np.any(M < 0): # sI - W o W is not an M-matrix
#     193         if iter == 1 or s <= 0.9:
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/scipy/linalg/_basic.py:958, in inv(a, overwrite_a, check_finite)
#     951     # XXX: the following line fixes curious SEGFAULT when
#     952     # benchmarking 500x500 matrix inverse. This seems to
#     953     # be a bug in LAPACK ?getri routine because if lwork is
#     954     # minimal (when using lwork[0] instead of lwork[1]) then
#     955     # all tests pass. Further investigation is required if
#     956     # more such SEGFAULTs occur.
#     957     lwork = int(1.01 * lwork)
# --> 958     inv_a, info = getri(lu, piv, lwork=lwork, overwrite_lu=1)
#     959 if info > 0:
#     960     raise LinAlgError("singular matrix")
#
# KeyboardInterrupt:

# %%
import pickle
import numpy as np

# %%
with open('./simulated_data/v9/X/X_1.pkl', 'rb') as f:
    X_data = pickle.load(f)
X = X_data['X']
with open('./simulated_data/v9/knockoff/knockoff_1.pkl', 'rb') as f:
    X_tilde = pickle.load(f)

# %%
W_true = X_data['W_true']

# %%
X_all = np.concatenate([X, X_tilde], axis=-1)

# %%
X_all.shape
# Out:
# (2000, 160)

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 160, 1000
graph_type, sem_type = 'ER', 'gauss'

model = linear.DagmaLinear(loss_type='l2') # create a linear model with least squares loss
W_est = model.fit(None, X_all, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# KeyboardInterrupt

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 80, 1000
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2') # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# Exception ignored in: <function tqdm.__del__ at 0x11aa0ee50>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/tqdm/std.py", line 1147, in __del__
#     def __del__(self):
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 12
#       9 X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)
#      11 model = linear.DagmaLinear(loss_type='l2') # create a linear model with least squares loss
# ---> 12 W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
#      13 acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
#      14 print(acc)
#
# File ~/Documents/dagma/src/dagma/linear.py:381, in DagmaLinear.fit(self, dagma_type, X, lambda1, w_threshold, T, mu_init, mu_factor, s, warm_iter, max_iter, lr, checkpoint, beta_1, beta_2, exclude_edges, include_edges, return_no_filter)
#     379 inner_iters = int(max_iter) if i == T - 1 else int(warm_iter)
#     380 while success is False:
# --> 381     W_temp, success = self.minimize(self.W_est.copy(), mu, inner_iters, s[i], lr=lr_adam, beta_1=beta_1, beta_2=beta_2, pbar=pbar)
#     382     if dagma_type == 'dagma_1':
#     383         W_temp = self.clean_diag(W_temp)
#
# File ~/Documents/dagma/src/dagma/linear.py:228, in DagmaLinear.minimize(self, W, mu, max_iter, s, lr, tol, beta_1, beta_2, pbar)
#     226             break
#     227         obj_prev = obj_new
# --> 228     pbar.update(1)
#     229 return W, True
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/tqdm/notebook.py:262, in tqdm_notebook.update(self, n)
#     260 def update(self, n=1):
#     261     try:
# --> 262         return super().update(n=n)
#     263     # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#     264     except:  # NOQA
#     265         # cannot catch KeyboardInterrupt when using manual tqdm
#     266         # as the interrupt will most likely happen on another statement
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/tqdm/std.py:1242, in tqdm.update(self, n)
#    1240     self._ema_dn(dn)
#    1241     self._ema_dt(dt)
# -> 1242 self.refresh(lock_args=self.lock_args)
#    1243 if self.dynamic_miniters:
#    1244     # If no `miniters` was specified, adjust automatically to the
#    1245     # maximum iteration rate seen so far between two prints.
#    1246     # e.g.: After running `tqdm.update(5)`, subsequent
#    1247     # calls to `tqdm.update()` will only cause an update after
#    1248     # at least 5 more iterations.
#    1249     if self.maxinterval and dt >= self.maxinterval:
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/tqdm/std.py:1347, in tqdm.refresh(self, nolock, lock_args)
#    1345     else:
#    1346         self._lock.acquire()
# -> 1347 self.display()
#    1348 if not nolock:
#    1349     self._lock.release()
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/tqdm/notebook.py:157, in tqdm_notebook.display(self, msg, pos, close, bar_style, check_delay)
#     154     msg = self.format_meter(**d)
#     156 ltext, pbar, rtext = self.container.children
# --> 157 pbar.value = self.n
#     159 if msg:
#     160     msg = msg.replace(' ', u'\u2007')  # fix html space padding
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/traitlets/traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:700, in Widget.notify_change(self, change)
#     696 if self.comm is not None and getattr(self.comm, 'kernel', True) is not None:
#     697     # Make sure this isn't information that the front-end just sent us.
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
# --> 700         self.send_state(key=name)
#     701 super().notify_change(change)
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:586, in Widget.send_state(self, key)
#     584 state, buffer_paths, buffers = _remove_buffers(state)
#     585 msg = {'method': 'update', 'state': state, 'buffer_paths': buffer_paths}
# --> 586 self._send(msg, buffers=buffers)
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/ipywidgets/widgets/widget.py:825, in Widget._send(self, msg, buffers)
#     823 """Sends a message to the model in the front-end."""
#     824 if self.comm is not None and (self.comm.kernel is not None if hasattr(self.comm, "kernel") else True):
# --> 825     self.comm.send(data=msg, buffers=buffers)
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/comm/base_comm.py:147, in BaseComm.send(self, data, metadata, buffers)
#     143 def send(
#     144     self, data: MaybeDict = None, metadata: MaybeDict = None, buffers: BuffersType = None
#     145 ) -> None:
#     146     """Send a message to the frontend-side version of this comm"""
# --> 147     self.publish_msg(
#     148         "comm_msg",
#     149         data=data,
#     150         metadata=metadata,
#     151         buffers=buffers,
#     152     )
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/ipykernel/comm/comm.py:37, in BaseComm.publish_msg(self, msg_type, data, metadata, buffers, **keys)
#      34     self.kernel = Kernel.instance()
#      36 assert self.kernel.session is not None
# ---> 37 self.kernel.session.send(
#      38     self.kernel.iopub_socket,
#      39     msg_type,
#      40     content,
#      41     metadata=json_clean(metadata),
#      42     parent=self.kernel.get_parent(),
#      43     ident=self.topic,
#      44     buffers=buffers,
#      45 )
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/jupyter_client/session.py:863, in Session.send(self, stream, msg_or_type, content, parent, ident, buffers, track, header, metadata)
#     860 elif stream:
#     861     # use dummy tracker, which will be done immediately
#     862     tracker = DONE
# --> 863     stream.send_multipart(to_send, copy=copy)
#     864 else:
#     865     tracker = DONE
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/ipykernel/iostream.py:346, in BackgroundSocket.send_multipart(self, *args, **kwargs)
#     344 """Schedule send in IO thread"""
#     345 assert self.io_thread is not None
# --> 346 return self.io_thread.send_multipart(*args, **kwargs)
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/ipykernel/iostream.py:276, in IOPubThread.send_multipart(self, *args, **kwargs)
#     271 def send_multipart(self, *args, **kwargs):
#     272     """send_multipart schedules actual zmq send in my thread.
#     273
#     274     If my thread isn't running (e.g. forked process), send immediately.
#     275     """
# --> 276     self.schedule(lambda: self._really_send(*args, **kwargs))
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/ipykernel/iostream.py:267, in IOPubThread.schedule(self, f)
#     265     self._events.append(f)
#     266     # wake event thread (message content is ignored)
# --> 267     self._event_pipe.send(b"")
#     268 else:
#     269     f()
#
# File /opt/anaconda3/envs/knockoff/lib/python3.9/site-packages/zmq/sugar/socket.py:701, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     694         data = zmq.Frame(
#     695             data,
#     696             track=track,
#     697             copy=copy or None,
#     698             copy_threshold=self.copy_threshold,
#     699         )
#     700     data.group = group
# --> 701 return super().send(data, flags=flags, copy=copy, track=track)
#
# File _zmq.py:1073, in zmq.backend.cython._zmq.Socket.send()
#
# File _zmq.py:1121, in zmq.backend.cython._zmq.Socket.send()
#
# File _zmq.py:1320, in zmq.backend.cython._zmq._send_copy()
#
# File _zmq.py:141, in zmq.backend.cython._zmq._check_rc()
#
# KeyboardInterrupt:

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 60, 1000
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2', verbose=True) # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# Iteration -- 1:
#
#
# Minimize with -- mu:1.0 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 1.5906e-01
# 	score(W_est): 1.8052e+16
# 	obj(W_est): 1.8052e+16
#
# Inner iteration 2000
# 	h(W_est): 2.2328e-01
# 	score(W_est): 1.6555e+12
# 	obj(W_est): 1.6555e+12
#
# Inner iteration 3000
# 	h(W_est): 2.2372e-01
# 	score(W_est): 1.9716e+10
# 	obj(W_est): 1.9716e+10
#
# Inner iteration 4000
# 	h(W_est): 2.2390e-01
# 	score(W_est): 1.9543e+10
# 	obj(W_est): 1.9543e+10
#
# Inner iteration 5000
# 	h(W_est): 2.2439e-01
# 	score(W_est): 1.9525e+10
# 	obj(W_est): 1.9525e+10
#
# Inner iteration 6000
# 	h(W_est): 2.2568e-01
# 	score(W_est): 1.9495e+10
# 	obj(W_est): 1.9495e+10
#
# Inner iteration 7000
# 	h(W_est): 2.2884e-01
# 	score(W_est): 1.9451e+10
# 	obj(W_est): 1.9451e+10
#
# Inner iteration 8000
# 	h(W_est): 2.3575e-01
# 	score(W_est): 1.9431e+10
# 	obj(W_est): 1.9431e+10
#
# Inner iteration 9000
# 	h(W_est): 2.4286e-01
# 	score(W_est): 1.9312e+10
# 	obj(W_est): 1.9312e+10
#
# Inner iteration 10000
# 	h(W_est): 2.5091e-01
# 	score(W_est): 1.9217e+10
# 	obj(W_est): 1.9217e+10
#
# Inner iteration 11000
# 	h(W_est): 2.5992e-01
# 	score(W_est): 1.9061e+10
# 	obj(W_est): 1.9061e+10
#
# Inner iteration 12000
# 	h(W_est): 2.6903e-01
# 	score(W_est): 1.8917e+10
# 	obj(W_est): 1.8917e+10
#
# Inner iteration 13000
# 	h(W_est): 2.7703e-01
# 	score(W_est): 1.8699e+10
# 	obj(W_est): 1.8699e+10
#
# Inner iteration 14000
# 	h(W_est): 2.8402e-01
# 	score(W_est): 1.8348e+10
# 	obj(W_est): 1.8348e+10
#
# Inner iteration 15000
# 	h(W_est): 2.9007e-01
# 	score(W_est): 1.7927e+10
# 	obj(W_est): 1.7927e+10
#
# Inner iteration 16000
# 	h(W_est): 2.9529e-01
# 	score(W_est): 1.7428e+10
# 	obj(W_est): 1.7428e+10
#
# Inner iteration 17000
# 	h(W_est): 2.9998e-01
# 	score(W_est): 1.6814e+10
# 	obj(W_est): 1.6814e+10
#
# Inner iteration 18000
# 	h(W_est): 3.0441e-01
# 	score(W_est): 1.6041e+10
# 	obj(W_est): 1.6041e+10
#
# Inner iteration 19000
# 	h(W_est): 3.0837e-01
# 	score(W_est): 1.5242e+10
# 	obj(W_est): 1.5242e+10
# Learning rate decreased to lr: 0.00015
# Learning rate decreased to lr: 7.5e-05
# Learning rate decreased to lr: 3.75e-05
# Learning rate decreased to lr: 1.875e-05
# Learning rate decreased to lr: 9.375e-06
# Learning rate decreased to lr: 4.6875e-06
# Learning rate decreased to lr: 2.34375e-06
# Learning rate decreased to lr: 1.171875e-06
# Learning rate decreased to lr: 5.859375e-07
# Learning rate decreased to lr: 2.9296875e-07
# Learning rate decreased to lr: 1.46484375e-07
# Learning rate decreased to lr: 7.32421875e-08
# Learning rate decreased to lr: 3.662109375e-08
# Learning rate decreased to lr: 1.8310546875e-08
# Learning rate decreased to lr: 9.1552734375e-09
# Learning rate decreased to lr: 4.57763671875e-09
# Learning rate decreased to lr: 2.288818359375e-09
# Learning rate decreased to lr: 1.1444091796875e-09
# Learning rate decreased to lr: 5.7220458984375e-10
# Learning rate decreased to lr: 2.86102294921875e-10
# Learning rate decreased to lr: 1.430511474609375e-10
# Learning rate decreased to lr: 7.152557373046874e-11
# Learning rate decreased to lr: 3.576278686523437e-11
# Learning rate decreased to lr: 1.7881393432617186e-11
# Learning rate decreased to lr: 8.940696716308593e-12
# Learning rate decreased to lr: 4.4703483581542965e-12
# Learning rate decreased to lr: 2.2351741790771482e-12
# Learning rate decreased to lr: 1.1175870895385741e-12
# Learning rate decreased to lr: 5.587935447692871e-13
# Learning rate decreased to lr: 2.7939677238464353e-13
# Learning rate decreased to lr: 1.3969838619232177e-13
# Learning rate decreased to lr: 6.984919309616088e-14
# Learning rate decreased to lr: 3.492459654808044e-14
# Learning rate decreased to lr: 1.746229827404022e-14
# Learning rate decreased to lr: 8.73114913702011e-15
# Learning rate decreased to lr: 4.365574568510055e-15
# Learning rate decreased to lr: 2.1827872842550276e-15
# Learning rate decreased to lr: 1.0913936421275138e-15
# Learning rate decreased to lr: 5.456968210637569e-16
# Learning rate decreased to lr: 2.7284841053187845e-16
# Learning rate decreased to lr: 1.3642420526593922e-16
#
# Iteration -- 2:
#
#
# Minimize with -- mu:0.1 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 3.0981e-01
# 	score(W_est): 1.5015e+10
# 	obj(W_est): 1.5015e+09
# Learning rate decreased to lr: 0.00015
# Learning rate decreased to lr: 7.5e-05
# Learning rate decreased to lr: 3.75e-05
# Learning rate decreased to lr: 1.875e-05
# Learning rate decreased to lr: 9.375e-06
# Learning rate decreased to lr: 4.6875e-06
# Learning rate decreased to lr: 2.34375e-06
# Learning rate decreased to lr: 1.171875e-06
# Learning rate decreased to lr: 5.859375e-07
# Learning rate decreased to lr: 2.9296875e-07
# Learning rate decreased to lr: 1.46484375e-07
# Learning rate decreased to lr: 7.32421875e-08
# Learning rate decreased to lr: 3.662109375e-08
# Learning rate decreased to lr: 1.8310546875e-08
# Learning rate decreased to lr: 9.1552734375e-09
# Learning rate decreased to lr: 4.57763671875e-09
# Learning rate decreased to lr: 2.288818359375e-09
# Learning rate decreased to lr: 1.1444091796875e-09
# Learning rate decreased to lr: 5.7220458984375e-10
# Learning rate decreased to lr: 2.86102294921875e-10
# Learning rate decreased to lr: 1.430511474609375e-10
# Learning rate decreased to lr: 7.152557373046874e-11
# Learning rate decreased to lr: 3.576278686523437e-11
# Learning rate decreased to lr: 1.7881393432617186e-11
# Learning rate decreased to lr: 8.940696716308593e-12
# Learning rate decreased to lr: 4.4703483581542965e-12
# Learning rate decreased to lr: 2.2351741790771482e-12
# Learning rate decreased to lr: 1.1175870895385741e-12
# Learning rate decreased to lr: 5.587935447692871e-13
# Learning rate decreased to lr: 2.7939677238464353e-13
# Learning rate decreased to lr: 1.3969838619232177e-13
# Learning rate decreased to lr: 6.984919309616088e-14
# Learning rate decreased to lr: 3.492459654808044e-14
# Learning rate decreased to lr: 1.746229827404022e-14
# Learning rate decreased to lr: 8.73114913702011e-15
# Learning rate decreased to lr: 4.365574568510055e-15
# Learning rate decreased to lr: 2.1827872842550276e-15
# Learning rate decreased to lr: 1.0913936421275138e-15
# Learning rate decreased to lr: 5.456968210637569e-16
# Learning rate decreased to lr: 2.7284841053187845e-16
# Learning rate decreased to lr: 1.3642420526593922e-16
#
# Iteration -- 3:
#
#
# Minimize with -- mu:0.010000000000000002 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 3.0991e-01
# 	score(W_est): 1.4904e+10
# 	obj(W_est): 1.4904e+08
# Learning rate decreased to lr: 0.00015
# Learning rate decreased to lr: 7.5e-05
# Learning rate decreased to lr: 3.75e-05
# Learning rate decreased to lr: 1.875e-05
# Learning rate decreased to lr: 9.375e-06
# Learning rate decreased to lr: 4.6875e-06
# Learning rate decreased to lr: 2.34375e-06
# Learning rate decreased to lr: 1.171875e-06
# Learning rate decreased to lr: 5.859375e-07
# Learning rate decreased to lr: 2.9296875e-07
# Learning rate decreased to lr: 1.46484375e-07
# Learning rate decreased to lr: 7.32421875e-08
# Learning rate decreased to lr: 3.662109375e-08
# Learning rate decreased to lr: 1.8310546875e-08
# Learning rate decreased to lr: 9.1552734375e-09
# Learning rate decreased to lr: 4.57763671875e-09
# Learning rate decreased to lr: 2.288818359375e-09
# Learning rate decreased to lr: 1.1444091796875e-09
# Learning rate decreased to lr: 5.7220458984375e-10
# Learning rate decreased to lr: 2.86102294921875e-10
# Learning rate decreased to lr: 1.430511474609375e-10
# Learning rate decreased to lr: 7.152557373046874e-11
# Learning rate decreased to lr: 3.576278686523437e-11
# Learning rate decreased to lr: 1.7881393432617186e-11
# Learning rate decreased to lr: 8.940696716308593e-12
# Learning rate decreased to lr: 4.4703483581542965e-12
# Learning rate decreased to lr: 2.2351741790771482e-12
# Learning rate decreased to lr: 1.1175870895385741e-12
# Learning rate decreased to lr: 5.587935447692871e-13
# Learning rate decreased to lr: 2.7939677238464353e-13
# Learning rate decreased to lr: 1.3969838619232177e-13
# Learning rate decreased to lr: 6.984919309616088e-14
# Learning rate decreased to lr: 3.492459654808044e-14
# Learning rate decreased to lr: 1.746229827404022e-14
# Learning rate decreased to lr: 8.73114913702011e-15
# Learning rate decreased to lr: 4.365574568510055e-15
# Learning rate decreased to lr: 2.1827872842550276e-15
# Learning rate decreased to lr: 1.0913936421275138e-15
# Learning rate decreased to lr: 5.456968210637569e-16
# Learning rate decreased to lr: 2.7284841053187845e-16
# Learning rate decreased to lr: 1.3642420526593922e-16
#
# Iteration -- 4:
#
#
# Minimize with -- mu:0.0010000000000000002 -- lr: 0.0003 -- s: 1.0999999999999999 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 2.7950e-01
# 	score(W_est): 1.4695e+10
# 	obj(W_est): 1.4695e+07
# Learning rate decreased to lr: 0.00015
# Learning rate decreased to lr: 7.5e-05
# Learning rate decreased to lr: 3.75e-05
# Learning rate decreased to lr: 1.875e-05
# Learning rate decreased to lr: 9.375e-06
# Learning rate decreased to lr: 4.6875e-06
# Learning rate decreased to lr: 2.34375e-06
# Learning rate decreased to lr: 1.171875e-06
# Learning rate decreased to lr: 5.859375e-07
# Learning rate decreased to lr: 2.9296875e-07
# Learning rate decreased to lr: 1.46484375e-07
# Learning rate decreased to lr: 7.32421875e-08
#
# Inner iteration 2000
# 	h(W_est): 2.7920e-01
# 	score(W_est): 1.4193e+10
# 	obj(W_est): 1.4193e+07
# Learning rate decreased to lr: 3.662109375e-08
# Learning rate decreased to lr: 1.8310546875e-08
# Learning rate decreased to lr: 9.1552734375e-09
# Learning rate decreased to lr: 4.57763671875e-09
# Learning rate decreased to lr: 2.288818359375e-09
# Learning rate decreased to lr: 1.1444091796875e-09
# Learning rate decreased to lr: 5.7220458984375e-10
# Learning rate decreased to lr: 2.86102294921875e-10
# Learning rate decreased to lr: 1.430511474609375e-10
# Learning rate decreased to lr: 7.152557373046874e-11
# Learning rate decreased to lr: 3.576278686523437e-11
# Learning rate decreased to lr: 1.7881393432617186e-11
# Learning rate decreased to lr: 8.940696716308593e-12
# Learning rate decreased to lr: 4.4703483581542965e-12
# Learning rate decreased to lr: 2.2351741790771482e-12
# Learning rate decreased to lr: 1.1175870895385741e-12
# Learning rate decreased to lr: 5.587935447692871e-13
# Learning rate decreased to lr: 2.7939677238464353e-13
# Learning rate decreased to lr: 1.3969838619232177e-13
# Learning rate decreased to lr: 6.984919309616088e-14
# Learning rate decreased to lr: 3.492459654808044e-14
# Learning rate decreased to lr: 1.746229827404022e-14
# Learning rate decreased to lr: 8.73114913702011e-15
# Learning rate decreased to lr: 4.365574568510055e-15
# Learning rate decreased to lr: 2.1827872842550276e-15
# Learning rate decreased to lr: 1.0913936421275138e-15
# Learning rate decreased to lr: 5.456968210637569e-16
# Learning rate decreased to lr: 2.7284841053187845e-16
# Learning rate decreased to lr: 1.3642420526593922e-16
#
# Iteration -- 5:
#
#
# Minimize with -- mu:0.00010000000000000003 -- lr: 0.0003 -- s: 0.9999999999999999 -- l1: 0.02 for 60000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 3.0770e-01
# 	score(W_est): 1.4270e+10
# 	obj(W_est): 1.4270e+06
#
# Inner iteration 2000
# 	h(W_est): 3.0406e-01
# 	score(W_est): 1.3619e+10
# 	obj(W_est): 1.3619e+06
# Learning rate decreased to lr: 0.00015
# Learning rate decreased to lr: 7.5e-05
#
# Inner iteration 3000
# 	h(W_est): 3.0243e-01
# 	score(W_est): 1.3294e+10
# 	obj(W_est): 1.3294e+06
# Learning rate decreased to lr: 3.75e-05
# Learning rate decreased to lr: 1.875e-05
# Learning rate decreased to lr: 9.375e-06
# Learning rate decreased to lr: 4.6875e-06
#
# Inner iteration 4000
# 	h(W_est): 3.0231e-01
# 	score(W_est): 1.3252e+10
# 	obj(W_est): 1.3252e+06
# Learning rate decreased to lr: 2.34375e-06
#
# Inner iteration 5000
# 	h(W_est): 3.0226e-01
# 	score(W_est): 1.3236e+10
# 	obj(W_est): 1.3236e+06
# Learning rate decreased to lr: 1.171875e-06
# Learning rate decreased to lr: 5.859375e-07
# Learning rate decreased to lr: 2.9296875e-07
#
# Inner iteration 6000
# 	h(W_est): 3.0225e-01
# 	score(W_est): 1.3230e+10
# 	obj(W_est): 1.3230e+06
# Learning rate decreased to lr: 1.46484375e-07
# Learning rate decreased to lr: 7.32421875e-08
# Learning rate decreased to lr: 3.662109375e-08
#
# Inner iteration 7000
# 	h(W_est): 3.0224e-01
# 	score(W_est): 1.3229e+10
# 	obj(W_est): 1.3229e+06
# Learning rate decreased to lr: 1.8310546875e-08
# Learning rate decreased to lr: 9.1552734375e-09
# Learning rate decreased to lr: 4.57763671875e-09
# Learning rate decreased to lr: 2.288818359375e-09
#
# Inner iteration 8000
# 	h(W_est): 3.0224e-01
# 	score(W_est): 1.3229e+10
# 	obj(W_est): 1.3229e+06
# Learning rate decreased to lr: 1.1444091796875e-09
# Learning rate decreased to lr: 5.7220458984375e-10
#
# Inner iteration 9000
# 	h(W_est): 3.0224e-01
# 	score(W_est): 1.3229e+10
# 	obj(W_est): 1.3229e+06
# Learning rate decreased to lr: 2.86102294921875e-10
# Learning rate decreased to lr: 1.430511474609375e-10
#
# Inner iteration 10000
# 	h(W_est): 3.0224e-01
# 	score(W_est): 1.3229e+10
# 	obj(W_est): 1.3229e+06
# {'fdr': 0.4390625, 'tpr': 0.359, 'fpr': 0.36493506493506495, 'shd': 922, 'nnz': 640}

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 60, 500
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2', verbose=False) # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# {'fdr': 0.5076530612244898, 'tpr': 0.772, 'fpr': 0.31338582677165355, 'shd': 506, 'nnz': 784}

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 30, 400
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2', verbose=False) # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# {'fdr': 0.06070287539936102, 'tpr': 0.735, 'fpr': 0.5428571428571428, 'shd': 119, 'nnz': 313}

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 60, 50
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2', verbose=True) # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# Iteration -- 1:
#
#
# Minimize with -- mu:1.0 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 2.8500e+00
# 	score(W_est): 2.4145e+01
# 	obj(W_est): 2.8753e+01
#
# Inner iteration 2000
# 	h(W_est): 4.9551e+00
# 	score(W_est): 1.2975e+01
# 	obj(W_est): 1.9584e+01
#
# Inner iteration 3000
# 	h(W_est): 5.6744e+00
# 	score(W_est): 1.0860e+01
# 	obj(W_est): 1.8078e+01
#
# Inner iteration 4000
# 	h(W_est): 5.8792e+00
# 	score(W_est): 1.0238e+01
# 	obj(W_est): 1.7608e+01
#
# Inner iteration 5000
# 	h(W_est): 5.8620e+00
# 	score(W_est): 1.0042e+01
# 	obj(W_est): 1.7370e+01
#
# Inner iteration 6000
# 	h(W_est): 5.7670e+00
# 	score(W_est): 9.9982e+00
# 	obj(W_est): 1.7222e+01
#
# Inner iteration 7000
# 	h(W_est): 5.6619e+00
# 	score(W_est): 1.0015e+01
# 	obj(W_est): 1.7129e+01
#
# Inner iteration 8000
# 	h(W_est): 5.5807e+00
# 	score(W_est): 1.0044e+01
# 	obj(W_est): 1.7074e+01
#
# Inner iteration 9000
# 	h(W_est): 5.5274e+00
# 	score(W_est): 1.0072e+01
# 	obj(W_est): 1.7045e+01
#
# Inner iteration 10000
# 	h(W_est): 5.4967e+00
# 	score(W_est): 1.0093e+01
# 	obj(W_est): 1.7031e+01
#
# Inner iteration 11000
# 	h(W_est): 5.4814e+00
# 	score(W_est): 1.0106e+01
# 	obj(W_est): 1.7027e+01
#
# Inner iteration 12000
# 	h(W_est): 5.4759e+00
# 	score(W_est): 1.0111e+01
# 	obj(W_est): 1.7027e+01
#
# Inner iteration 13000
# 	h(W_est): 5.4755e+00
# 	score(W_est): 1.0112e+01
# 	obj(W_est): 1.7027e+01
#
# Inner iteration 14000
# 	h(W_est): 5.4755e+00
# 	score(W_est): 1.0112e+01
# 	obj(W_est): 1.7027e+01
#
# Inner iteration 15000
# 	h(W_est): 5.4754e+00
# 	score(W_est): 1.0112e+01
# 	obj(W_est): 1.7027e+01
#
# Iteration -- 2:
#
#
# Minimize with -- mu:0.1 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 6.9671e-01
# 	score(W_est): 2.1143e+01
# 	obj(W_est): 2.9624e+00
#
# Inner iteration 2000
# 	h(W_est): 3.7795e-01
# 	score(W_est): 2.2530e+01
# 	obj(W_est): 2.7857e+00
#
# Inner iteration 3000
# 	h(W_est): 3.1905e-01
# 	score(W_est): 2.2766e+01
# 	obj(W_est): 2.7501e+00
#
# Inner iteration 4000
# 	h(W_est): 2.9699e-01
# 	score(W_est): 2.2929e+01
# 	obj(W_est): 2.7439e+00
#
# Inner iteration 5000
# 	h(W_est): 2.9089e-01
# 	score(W_est): 2.2986e+01
# 	obj(W_est): 2.7435e+00
#
# Inner iteration 6000
# 	h(W_est): 2.9018e-01
# 	score(W_est): 2.2993e+01
# 	obj(W_est): 2.7435e+00
#
# Inner iteration 7000
# 	h(W_est): 2.9019e-01
# 	score(W_est): 2.2993e+01
# 	obj(W_est): 2.7435e+00
#
# Inner iteration 8000
# 	h(W_est): 2.9018e-01
# 	score(W_est): 2.2993e+01
# 	obj(W_est): 2.7435e+00
#
# Iteration -- 3:
#
#
# Minimize with -- mu:0.010000000000000002 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 1.0166e-02
# 	score(W_est): 2.8940e+01
# 	obj(W_est): 3.1501e-01
#
# Inner iteration 2000
# 	h(W_est): 6.9615e-03
# 	score(W_est): 2.8839e+01
# 	obj(W_est): 3.1070e-01
#
# Inner iteration 3000
# 	h(W_est): 5.5177e-03
# 	score(W_est): 2.8815e+01
# 	obj(W_est): 3.0893e-01
#
# Inner iteration 4000
# 	h(W_est): 4.8287e-03
# 	score(W_est): 2.8814e+01
# 	obj(W_est): 3.0817e-01
#
# Inner iteration 5000
# 	h(W_est): 4.5088e-03
# 	score(W_est): 2.8820e+01
# 	obj(W_est): 3.0788e-01
#
# Inner iteration 6000
# 	h(W_est): 4.4029e-03
# 	score(W_est): 2.8825e+01
# 	obj(W_est): 3.0780e-01
#
# Inner iteration 7000
# 	h(W_est): 4.3751e-03
# 	score(W_est): 2.8828e+01
# 	obj(W_est): 3.0779e-01
#
# Inner iteration 8000
# 	h(W_est): 4.3713e-03
# 	score(W_est): 2.8828e+01
# 	obj(W_est): 3.0779e-01
#
# Inner iteration 9000
# 	h(W_est): 4.3717e-03
# 	score(W_est): 2.8828e+01
# 	obj(W_est): 3.0779e-01
#
# Iteration -- 4:
#
#
# Minimize with -- mu:0.0010000000000000002 -- lr: 0.0003 -- s: 1.0999999999999999 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 6.0894e-05
# 	score(W_est): 2.9600e+01
# 	obj(W_est): 3.1158e-02
#
# Inner iteration 2000
# 	h(W_est): 5.6559e-05
# 	score(W_est): 2.9594e+01
# 	obj(W_est): 3.1142e-02
#
# Inner iteration 3000
# 	h(W_est): 5.3854e-05
# 	score(W_est): 2.9591e+01
# 	obj(W_est): 3.1133e-02
#
# Inner iteration 4000
# 	h(W_est): 5.3068e-05
# 	score(W_est): 2.9591e+01
# 	obj(W_est): 3.1132e-02
#
# Inner iteration 5000
# 	h(W_est): 5.3039e-05
# 	score(W_est): 2.9591e+01
# 	obj(W_est): 3.1132e-02
#
# Iteration -- 5:
#
#
# Minimize with -- mu:0.00010000000000000003 -- lr: 0.0003 -- s: 0.9999999999999999 -- l1: 0.02 for 60000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 1.2810e-06
# 	score(W_est): 2.9736e+01
# 	obj(W_est): 3.1200e-03
#
# Inner iteration 2000
# 	h(W_est): 1.2806e-06
# 	score(W_est): 2.9736e+01
# 	obj(W_est): 3.1200e-03
# {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'nnz': 50}

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 60, 240
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2', verbose=True) # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# Iteration -- 1:
#
#
# Minimize with -- mu:1.0 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 1.0404e+00
# 	score(W_est): 1.4738e+03
# 	obj(W_est): 1.4792e+03
#
# Inner iteration 2000
# 	h(W_est): 1.7775e+00
# 	score(W_est): 1.3106e+02
# 	obj(W_est): 1.3782e+02
#
# Inner iteration 3000
# 	h(W_est): 2.2930e+00
# 	score(W_est): 5.2371e+01
# 	obj(W_est): 5.9783e+01
#
# Inner iteration 4000
# 	h(W_est): 2.6794e+00
# 	score(W_est): 3.4247e+01
# 	obj(W_est): 4.2048e+01
#
# Inner iteration 5000
# 	h(W_est): 2.9758e+00
# 	score(W_est): 2.4523e+01
# 	obj(W_est): 3.2586e+01
#
# Inner iteration 6000
# 	h(W_est): 3.1945e+00
# 	score(W_est): 1.7741e+01
# 	obj(W_est): 2.5951e+01
#
# Inner iteration 7000
# 	h(W_est): 3.3462e+00
# 	score(W_est): 1.3162e+01
# 	obj(W_est): 2.1418e+01
#
# Inner iteration 8000
# 	h(W_est): 3.4500e+00
# 	score(W_est): 1.0270e+01
# 	obj(W_est): 1.8493e+01
#
# Inner iteration 9000
# 	h(W_est): 3.5151e+00
# 	score(W_est): 8.4978e+00
# 	obj(W_est): 1.6654e+01
#
# Inner iteration 10000
# 	h(W_est): 3.5605e+00
# 	score(W_est): 7.3377e+00
# 	obj(W_est): 1.5417e+01
#
# Inner iteration 11000
# 	h(W_est): 3.5950e+00
# 	score(W_est): 6.5673e+00
# 	obj(W_est): 1.4557e+01
#
# Inner iteration 12000
# 	h(W_est): 3.6177e+00
# 	score(W_est): 6.0882e+00
# 	obj(W_est): 1.3980e+01
#
# Inner iteration 13000
# 	h(W_est): 3.6213e+00
# 	score(W_est): 5.8122e+00
# 	obj(W_est): 1.3611e+01
#
# Inner iteration 14000
# 	h(W_est): 3.6143e+00
# 	score(W_est): 5.6531e+00
# 	obj(W_est): 1.3372e+01
#
# Inner iteration 15000
# 	h(W_est): 3.6093e+00
# 	score(W_est): 5.5571e+00
# 	obj(W_est): 1.3224e+01
#
# Inner iteration 16000
# 	h(W_est): 3.5987e+00
# 	score(W_est): 5.5042e+00
# 	obj(W_est): 1.3127e+01
#
# Inner iteration 17000
# 	h(W_est): 3.5910e+00
# 	score(W_est): 5.4684e+00
# 	obj(W_est): 1.3054e+01
#
# Inner iteration 18000
# 	h(W_est): 3.5916e+00
# 	score(W_est): 5.4433e+00
# 	obj(W_est): 1.2996e+01
#
# Inner iteration 19000
# 	h(W_est): 3.6011e+00
# 	score(W_est): 5.4241e+00
# 	obj(W_est): 1.2949e+01
#
# Inner iteration 20000
# 	h(W_est): 3.6153e+00
# 	score(W_est): 5.4106e+00
# 	obj(W_est): 1.2923e+01
#
# Inner iteration 21000
# 	h(W_est): 3.6207e+00
# 	score(W_est): 5.4066e+00
# 	obj(W_est): 1.2914e+01
#
# Inner iteration 22000
# 	h(W_est): 3.6241e+00
# 	score(W_est): 5.4048e+00
# 	obj(W_est): 1.2908e+01
#
# Inner iteration 23000
# 	h(W_est): 3.6250e+00
# 	score(W_est): 5.4038e+00
# 	obj(W_est): 1.2905e+01
#
# Inner iteration 24000
# 	h(W_est): 3.6219e+00
# 	score(W_est): 5.4051e+00
# 	obj(W_est): 1.2904e+01
#
# Inner iteration 25000
# 	h(W_est): 3.6202e+00
# 	score(W_est): 5.4063e+00
# 	obj(W_est): 1.2904e+01
#
# Iteration -- 2:
#
#
# Minimize with -- mu:0.1 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 7.6127e-01
# 	score(W_est): 1.1303e+01
# 	obj(W_est): 2.3890e+00
#
# Inner iteration 2000
# 	h(W_est): 5.1367e-01
# 	score(W_est): 1.2014e+01
# 	obj(W_est): 2.2459e+00
#
# Inner iteration 3000
# 	h(W_est): 4.5642e-01
# 	score(W_est): 1.2214e+01
# 	obj(W_est): 2.2185e+00
#
# Inner iteration 4000
# 	h(W_est): 4.3188e-01
# 	score(W_est): 1.2325e+01
# 	obj(W_est): 2.2084e+00
#
# Inner iteration 5000
# 	h(W_est): 4.1956e-01
# 	score(W_est): 1.2392e+01
# 	obj(W_est): 2.2041e+00
#
# Inner iteration 6000
# 	h(W_est): 4.1447e-01
# 	score(W_est): 1.2434e+01
# 	obj(W_est): 2.2031e+00
#
# Inner iteration 7000
# 	h(W_est): 4.1347e-01
# 	score(W_est): 1.2444e+01
# 	obj(W_est): 2.2031e+00
#
# Inner iteration 8000
# 	h(W_est): 4.1341e-01
# 	score(W_est): 1.2445e+01
# 	obj(W_est): 2.2031e+00
#
# Iteration -- 3:
#
#
# Minimize with -- mu:0.010000000000000002 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 6.6945e-02
# 	score(W_est): 2.0387e+01
# 	obj(W_est): 3.3331e-01
#
# Inner iteration 2000
# 	h(W_est): 4.9046e-02
# 	score(W_est): 2.0809e+01
# 	obj(W_est): 3.2052e-01
#
# Inner iteration 3000
# 	h(W_est): 4.2688e-02
# 	score(W_est): 2.1101e+01
# 	obj(W_est): 3.1693e-01
#
# Inner iteration 4000
# 	h(W_est): 3.9912e-02
# 	score(W_est): 2.1308e+01
# 	obj(W_est): 3.1596e-01
#
# Inner iteration 5000
# 	h(W_est): 3.8821e-02
# 	score(W_est): 2.1415e+01
# 	obj(W_est): 3.1580e-01
#
# Inner iteration 6000
# 	h(W_est): 3.8602e-02
# 	score(W_est): 2.1442e+01
# 	obj(W_est): 3.1579e-01
#
# Inner iteration 7000
# 	h(W_est): 3.8572e-02
# 	score(W_est): 2.1446e+01
# 	obj(W_est): 3.1579e-01
#
# Iteration -- 4:
#
#
# Minimize with -- mu:0.0010000000000000002 -- lr: 0.0003 -- s: 1.0999999999999999 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 2.3991e-03
# 	score(W_est): 2.8553e+01
# 	obj(W_est): 3.7542e-02
#
# Inner iteration 2000
# 	h(W_est): 1.4290e-03
# 	score(W_est): 2.8556e+01
# 	obj(W_est): 3.6483e-02
#
# Inner iteration 3000
# 	h(W_est): 1.0019e-03
# 	score(W_est): 2.8610e+01
# 	obj(W_est): 3.5963e-02
#
# Inner iteration 4000
# 	h(W_est): 7.7281e-04
# 	score(W_est): 2.8712e+01
# 	obj(W_est): 3.5716e-02
#
# Inner iteration 5000
# 	h(W_est): 6.5453e-04
# 	score(W_est): 2.8793e+01
# 	obj(W_est): 3.5594e-02
#
# Inner iteration 6000
# 	h(W_est): 6.3334e-04
# 	score(W_est): 2.8798e+01
# 	obj(W_est): 3.5547e-02
#
# Inner iteration 7000
# 	h(W_est): 6.4226e-04
# 	score(W_est): 2.8779e+01
# 	obj(W_est): 3.5540e-02
#
# Inner iteration 8000
# 	h(W_est): 6.4243e-04
# 	score(W_est): 2.8778e+01
# 	obj(W_est): 3.5540e-02
#
# Inner iteration 9000
# 	h(W_est): 6.4269e-04
# 	score(W_est): 2.8777e+01
# 	obj(W_est): 3.5540e-02
#
# Iteration -- 5:
#
#
# Minimize with -- mu:0.00010000000000000003 -- lr: 0.0003 -- s: 0.9999999999999999 -- l1: 0.02 for 60000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 8.0662e-06
# 	score(W_est): 3.0025e+01
# 	obj(W_est): 3.6276e-03
#
# Inner iteration 2000
# 	h(W_est): 4.9535e-06
# 	score(W_est): 2.9928e+01
# 	obj(W_est): 3.6114e-03
#
# Inner iteration 3000
# 	h(W_est): 3.8777e-06
# 	score(W_est): 2.9886e+01
# 	obj(W_est): 3.6051e-03
#
# Inner iteration 4000
# 	h(W_est): 3.4097e-06
# 	score(W_est): 2.9862e+01
# 	obj(W_est): 3.6018e-03
#
# Inner iteration 5000
# 	h(W_est): 3.1577e-06
# 	score(W_est): 2.9851e+01
# 	obj(W_est): 3.6003e-03
#
# Inner iteration 6000
# 	h(W_est): 3.1345e-06
# 	score(W_est): 2.9847e+01
# 	obj(W_est): 3.6001e-03
#
# Inner iteration 7000
# 	h(W_est): 3.1328e-06
# 	score(W_est): 2.9846e+01
# 	obj(W_est): 3.6001e-03
#
# Inner iteration 8000
# 	h(W_est): 3.1287e-06
# 	score(W_est): 2.9846e+01
# 	obj(W_est): 3.6001e-03
#
# Inner iteration 9000
# 	h(W_est): 3.1389e-06
# 	score(W_est): 2.9846e+01
# 	obj(W_est): 3.6001e-03
#
# Inner iteration 10000
# 	h(W_est): 3.0963e-06
# 	score(W_est): 2.9846e+01
# 	obj(W_est): 3.6001e-03
#
# Inner iteration 11000
# 	h(W_est): 3.1397e-06
# 	score(W_est): 2.9846e+01
# 	obj(W_est): 3.6001e-03
#
# Inner iteration 12000
# 	h(W_est): 3.1382e-06
# 	score(W_est): 2.9846e+01
# 	obj(W_est): 3.6001e-03
#
# Inner iteration 13000
# 	h(W_est): 3.1617e-06
# 	score(W_est): 2.9846e+01
# 	obj(W_est): 3.6001e-03
# {'fdr': 0.016597510373443983, 'tpr': 0.9875, 'fpr': 0.00261437908496732, 'shd': 6, 'nnz': 241}

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 60, 30 * 59 - 100
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2', verbose=True) # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# Iteration -- 1:
#
#
# Minimize with -- mu:1.0 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 1.7381e-01
# 	score(W_est): 3.1205e+16
# 	obj(W_est): 3.1205e+16
#
# Inner iteration 2000
# 	h(W_est): 2.7363e-01
# 	score(W_est): 2.3576e+14
# 	obj(W_est): 2.3576e+14
#
# Inner iteration 3000
# 	h(W_est): 2.8924e-01
# 	score(W_est): 2.0897e+13
# 	obj(W_est): 2.0897e+13
#
# Inner iteration 4000
# 	h(W_est): 2.9758e-01
# 	score(W_est): 2.0524e+13
# 	obj(W_est): 2.0524e+13
#
# Inner iteration 5000
# 	h(W_est): 3.1120e-01
# 	score(W_est): 2.0023e+13
# 	obj(W_est): 2.0023e+13
#
# Inner iteration 6000
# 	h(W_est): 3.3526e-01
# 	score(W_est): 1.9336e+13
# 	obj(W_est): 1.9336e+13
#
# Inner iteration 7000
# 	h(W_est): 3.7274e-01
# 	score(W_est): 1.8405e+13
# 	obj(W_est): 1.8405e+13
#
# Inner iteration 8000
# 	h(W_est): 4.1637e-01
# 	score(W_est): 1.7153e+13
# 	obj(W_est): 1.7153e+13
#
# Inner iteration 9000
# 	h(W_est): 4.4271e-01
# 	score(W_est): 1.5491e+13
# 	obj(W_est): 1.5491e+13
#
# Inner iteration 10000
# 	h(W_est): 4.6399e-01
# 	score(W_est): 1.3354e+13
# 	obj(W_est): 1.3354e+13
#
# Inner iteration 11000
# 	h(W_est): 4.8596e-01
# 	score(W_est): 1.0756e+13
# 	obj(W_est): 1.0756e+13
#
# Inner iteration 12000
# 	h(W_est): 5.1444e-01
# 	score(W_est): 7.8885e+12
# 	obj(W_est): 7.8885e+12
#
# Inner iteration 13000
# 	h(W_est): 5.5375e-01
# 	score(W_est): 5.1359e+12
# 	obj(W_est): 5.1359e+12
#
# Inner iteration 14000
# 	h(W_est): 6.0555e-01
# 	score(W_est): 2.9390e+12
# 	obj(W_est): 2.9390e+12
#
# Inner iteration 15000
# 	h(W_est): 6.6091e-01
# 	score(W_est): 1.5236e+12
# 	obj(W_est): 1.5236e+12
#
# Inner iteration 16000
# 	h(W_est): 7.0197e-01
# 	score(W_est): 7.2013e+11
# 	obj(W_est): 7.2013e+11
#
# Inner iteration 17000
# 	h(W_est): 7.2002e-01
# 	score(W_est): 2.5544e+11
# 	obj(W_est): 2.5544e+11
#
# Inner iteration 18000
# 	h(W_est): 7.2668e-01
# 	score(W_est): 4.8536e+10
# 	obj(W_est): 4.8536e+10
#
# Inner iteration 19000
# 	h(W_est): 7.3047e-01
# 	score(W_est): 4.6296e+09
# 	obj(W_est): 4.6296e+09
#
# Inner iteration 20000
# 	h(W_est): 7.3225e-01
# 	score(W_est): 1.9510e+09
# 	obj(W_est): 1.9510e+09
#
# Inner iteration 21000
# 	h(W_est): 7.3320e-01
# 	score(W_est): 1.6561e+09
# 	obj(W_est): 1.6561e+09
#
# Inner iteration 22000
# 	h(W_est): 7.3399e-01
# 	score(W_est): 1.3199e+09
# 	obj(W_est): 1.3199e+09
#
# Inner iteration 23000
# 	h(W_est): 7.3468e-01
# 	score(W_est): 1.0319e+09
# 	obj(W_est): 1.0319e+09
#
# Inner iteration 24000
# 	h(W_est): 7.3528e-01
# 	score(W_est): 7.9129e+08
# 	obj(W_est): 7.9129e+08
#
# Inner iteration 25000
# 	h(W_est): 7.3584e-01
# 	score(W_est): 5.9425e+08
# 	obj(W_est): 5.9425e+08
#
# Inner iteration 26000
# 	h(W_est): 7.3637e-01
# 	score(W_est): 4.5230e+08
# 	obj(W_est): 4.5230e+08
#
# Inner iteration 27000
# 	h(W_est): 7.3688e-01
# 	score(W_est): 3.3006e+08
# 	obj(W_est): 3.3006e+08
#
# Inner iteration 28000
# 	h(W_est): 7.3736e-01
# 	score(W_est): 2.4571e+08
# 	obj(W_est): 2.4571e+08
#
# Inner iteration 29000
# 	h(W_est): 7.3780e-01
# 	score(W_est): 1.8039e+08
# 	obj(W_est): 1.8039e+08
#
# Inner iteration 30000
# 	h(W_est): 7.3820e-01
# 	score(W_est): 1.3263e+08
# 	obj(W_est): 1.3263e+08
#
# Iteration -- 2:
#
#
# Minimize with -- mu:0.1 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 7.3821e-01
# 	score(W_est): 2.5272e+08
# 	obj(W_est): 2.5272e+07
#
# Inner iteration 2000
# 	h(W_est): 7.3822e-01
# 	score(W_est): 4.4814e+07
# 	obj(W_est): 4.4814e+06
#
# Inner iteration 3000
# 	h(W_est): 7.3824e-01
# 	score(W_est): 4.1366e+07
# 	obj(W_est): 4.1366e+06
#
# Inner iteration 4000
# 	h(W_est): 7.3827e-01
# 	score(W_est): 3.6747e+07
# 	obj(W_est): 3.6747e+06
#
# Inner iteration 5000
# 	h(W_est): 7.3833e-01
# 	score(W_est): 3.1069e+07
# 	obj(W_est): 3.1069e+06
#
# Inner iteration 6000
# 	h(W_est): 7.3841e-01
# 	score(W_est): 2.4821e+07
# 	obj(W_est): 2.4821e+06
#
# Inner iteration 7000
# 	h(W_est): 7.3853e-01
# 	score(W_est): 1.8987e+07
# 	obj(W_est): 1.8987e+06
#
# Inner iteration 8000
# 	h(W_est): 7.3870e-01
# 	score(W_est): 1.4727e+07
# 	obj(W_est): 1.4727e+06
#
# Inner iteration 9000
# 	h(W_est): 7.3885e-01
# 	score(W_est): 1.6553e+07
# 	obj(W_est): 1.6553e+06
#
# Inner iteration 10000
# 	h(W_est): 7.3901e-01
# 	score(W_est): 1.4804e+08
# 	obj(W_est): 1.4804e+07
#
# Inner iteration 11000
# 	h(W_est): 7.3918e-01
# 	score(W_est): 5.8559e+07
# 	obj(W_est): 5.8559e+06
#
# Inner iteration 12000
# 	h(W_est): 7.3936e-01
# 	score(W_est): 7.8519e+07
# 	obj(W_est): 7.8519e+06
#
# Inner iteration 13000
# 	h(W_est): 7.3954e-01
# 	score(W_est): 9.5061e+07
# 	obj(W_est): 9.5061e+06
#
# Inner iteration 14000
# 	h(W_est): 7.3973e-01
# 	score(W_est): 1.1493e+08
# 	obj(W_est): 1.1493e+07
#
# Inner iteration 15000
# 	h(W_est): 7.3992e-01
# 	score(W_est): 1.2393e+08
# 	obj(W_est): 1.2393e+07
#
# Inner iteration 16000
# 	h(W_est): 7.4010e-01
# 	score(W_est): 1.0795e+08
# 	obj(W_est): 1.0795e+07
#
# Inner iteration 17000
# 	h(W_est): 7.4029e-01
# 	score(W_est): 9.1711e+07
# 	obj(W_est): 9.1711e+06
#
# Inner iteration 18000
# 	h(W_est): 7.4047e-01
# 	score(W_est): 8.5980e+07
# 	obj(W_est): 8.5980e+06
#
# Inner iteration 19000
# 	h(W_est): 7.4066e-01
# 	score(W_est): 9.5929e+07
# 	obj(W_est): 9.5929e+06
#
# Inner iteration 20000
# 	h(W_est): 7.4085e-01
# 	score(W_est): 1.1254e+08
# 	obj(W_est): 1.1254e+07
#
# Inner iteration 21000
# 	h(W_est): 7.4104e-01
# 	score(W_est): 1.1953e+08
# 	obj(W_est): 1.1953e+07
#
# Inner iteration 22000
# 	h(W_est): 7.4122e-01
# 	score(W_est): 1.0964e+08
# 	obj(W_est): 1.0964e+07
#
# Inner iteration 23000
# 	h(W_est): 7.4141e-01
# 	score(W_est): 9.3005e+07
# 	obj(W_est): 9.3005e+06
#
# Inner iteration 24000
# 	h(W_est): 7.4160e-01
# 	score(W_est): 8.5619e+07
# 	obj(W_est): 8.5619e+06
#
# Inner iteration 25000
# 	h(W_est): 7.4178e-01
# 	score(W_est): 9.4062e+07
# 	obj(W_est): 9.4062e+06
#
# Inner iteration 26000
# 	h(W_est): 7.4197e-01
# 	score(W_est): 1.1072e+08
# 	obj(W_est): 1.1072e+07
#
# Inner iteration 27000
# 	h(W_est): 7.4216e-01
# 	score(W_est): 1.1942e+08
# 	obj(W_est): 1.1942e+07
#
# Inner iteration 28000
# 	h(W_est): 7.4235e-01
# 	score(W_est): 1.1115e+08
# 	obj(W_est): 1.1115e+07
#
# Inner iteration 29000
# 	h(W_est): 7.4254e-01
# 	score(W_est): 9.4423e+07
# 	obj(W_est): 9.4423e+06
#
# Inner iteration 30000
# 	h(W_est): 7.4272e-01
# 	score(W_est): 8.5462e+07
# 	obj(W_est): 8.5462e+06
#
# Iteration -- 3:
#
#
# Minimize with -- mu:0.010000000000000002 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 7.4272e-01
# 	score(W_est): 2.2642e+08
# 	obj(W_est): 2.2642e+06
#
# Inner iteration 2000
# 	h(W_est): 7.4268e-01
# 	score(W_est): 1.1393e+07
# 	obj(W_est): 1.1393e+05
#
# Inner iteration 3000
# 	h(W_est): 7.4263e-01
# 	score(W_est): 1.1380e+07
# 	obj(W_est): 1.1380e+05
#
# Inner iteration 4000
# 	h(W_est): 7.4255e-01
# 	score(W_est): 1.1375e+07
# 	obj(W_est): 1.1375e+05
#
# Inner iteration 5000
# 	h(W_est): 7.4243e-01
# 	score(W_est): 1.1368e+07
# 	obj(W_est): 1.1368e+05
#
# Inner iteration 6000
# 	h(W_est): 7.4225e-01
# 	score(W_est): 1.1357e+07
# 	obj(W_est): 1.1357e+05
#
# Inner iteration 7000
# 	h(W_est): 7.4201e-01
# 	score(W_est): 1.1340e+07
# 	obj(W_est): 1.1341e+05
#
# Inner iteration 8000
# 	h(W_est): 7.4173e-01
# 	score(W_est): 1.1316e+07
# 	obj(W_est): 1.1316e+05
#
# Inner iteration 9000
# 	h(W_est): 7.4156e-01
# 	score(W_est): 1.4973e+07
# 	obj(W_est): 1.4973e+05
#
# Inner iteration 10000
# 	h(W_est): 7.4143e-01
# 	score(W_est): 1.3352e+08
# 	obj(W_est): 1.3352e+06
#
# Inner iteration 11000
# 	h(W_est): 7.4133e-01
# 	score(W_est): 8.4784e+07
# 	obj(W_est): 8.4784e+05
#
# Inner iteration 12000
# 	h(W_est): 7.4127e-01
# 	score(W_est): 9.8451e+07
# 	obj(W_est): 9.8451e+05
#
# Inner iteration 13000
# 	h(W_est): 7.4123e-01
# 	score(W_est): 1.1262e+08
# 	obj(W_est): 1.1262e+06
#
# Inner iteration 14000
# 	h(W_est): 7.4121e-01
# 	score(W_est): 1.0734e+08
# 	obj(W_est): 1.0734e+06
#
# Inner iteration 15000
# 	h(W_est): 7.4120e-01
# 	score(W_est): 1.0153e+08
# 	obj(W_est): 1.0153e+06
#
# Inner iteration 16000
# 	h(W_est): 7.4120e-01
# 	score(W_est): 9.6055e+07
# 	obj(W_est): 9.6055e+05
#
# Inner iteration 17000
# 	h(W_est): 7.4120e-01
# 	score(W_est): 9.6011e+07
# 	obj(W_est): 9.6011e+05
#
# Inner iteration 18000
# 	h(W_est): 7.4121e-01
# 	score(W_est): 1.0182e+08
# 	obj(W_est): 1.0182e+06
#
# Inner iteration 19000
# 	h(W_est): 7.4121e-01
# 	score(W_est): 1.0766e+08
# 	obj(W_est): 1.0766e+06
#
# Inner iteration 20000
# 	h(W_est): 7.4122e-01
# 	score(W_est): 1.0760e+08
# 	obj(W_est): 1.0760e+06
#
# Inner iteration 21000
# 	h(W_est): 7.4124e-01
# 	score(W_est): 1.0207e+08
# 	obj(W_est): 1.0207e+06
#
# Inner iteration 22000
# 	h(W_est): 7.4124e-01
# 	score(W_est): 9.6272e+07
# 	obj(W_est): 9.6272e+05
#
# Inner iteration 23000
# 	h(W_est): 7.4126e-01
# 	score(W_est): 9.5499e+07
# 	obj(W_est): 9.5499e+05
#
# Inner iteration 24000
# 	h(W_est): 7.4127e-01
# 	score(W_est): 1.0086e+08
# 	obj(W_est): 1.0086e+06
#
# Inner iteration 25000
# 	h(W_est): 7.4129e-01
# 	score(W_est): 1.0707e+08
# 	obj(W_est): 1.0707e+06
#
# Inner iteration 26000
# 	h(W_est): 7.4130e-01
# 	score(W_est): 1.0776e+08
# 	obj(W_est): 1.0776e+06
#
# Inner iteration 27000
# 	h(W_est): 7.4131e-01
# 	score(W_est): 1.0262e+08
# 	obj(W_est): 1.0262e+06
#
# Inner iteration 28000
# 	h(W_est): 7.4133e-01
# 	score(W_est): 9.6556e+07
# 	obj(W_est): 9.6556e+05
#
# Inner iteration 29000
# 	h(W_est): 7.4135e-01
# 	score(W_est): 9.5069e+07
# 	obj(W_est): 9.5069e+05
#
# Inner iteration 30000
# 	h(W_est): 7.4136e-01
# 	score(W_est): 9.9921e+07
# 	obj(W_est): 9.9921e+05
#
# Iteration -- 4:
#
#
# Minimize with -- mu:0.0010000000000000002 -- lr: 0.0003 -- s: 1.0999999999999999 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 6.6706e-01
# 	score(W_est): 2.1513e+08
# 	obj(W_est): 2.1513e+05
#
# Inner iteration 2000
# 	h(W_est): 6.6701e-01
# 	score(W_est): 1.0680e+07
# 	obj(W_est): 1.0680e+04
#
# Inner iteration 3000
# 	h(W_est): 6.6691e-01
# 	score(W_est): 1.0669e+07
# 	obj(W_est): 1.0669e+04
#
# Inner iteration 4000
# 	h(W_est): 6.6676e-01
# 	score(W_est): 1.0664e+07
# 	obj(W_est): 1.0665e+04
#
# Inner iteration 5000
# 	h(W_est): 6.6652e-01
# 	score(W_est): 1.0658e+07
# 	obj(W_est): 1.0658e+04
#
# Inner iteration 6000
# 	h(W_est): 6.6619e-01
# 	score(W_est): 1.0647e+07
# 	obj(W_est): 1.0648e+04
#
# Inner iteration 7000
# 	h(W_est): 6.6572e-01
# 	score(W_est): 1.0632e+07
# 	obj(W_est): 1.0632e+04
#
# Inner iteration 8000
# 	h(W_est): 6.6510e-01
# 	score(W_est): 1.0609e+07
# 	obj(W_est): 1.0609e+04
#
# Inner iteration 9000
# 	h(W_est): 6.6463e-01
# 	score(W_est): 1.3863e+07
# 	obj(W_est): 1.3864e+04
#
# Inner iteration 10000
# 	h(W_est): 6.6416e-01
# 	score(W_est): 1.2615e+08
# 	obj(W_est): 1.2615e+05
#
# Inner iteration 11000
# 	h(W_est): 6.6368e-01
# 	score(W_est): 8.7184e+07
# 	obj(W_est): 8.7185e+04
#
# Inner iteration 12000
# 	h(W_est): 6.6319e-01
# 	score(W_est): 1.0909e+08
# 	obj(W_est): 1.0910e+05
#
# Inner iteration 13000
# 	h(W_est): 6.6274e-01
# 	score(W_est): 1.0134e+08
# 	obj(W_est): 1.0134e+05
#
# Inner iteration 14000
# 	h(W_est): 6.6232e-01
# 	score(W_est): 9.9457e+07
# 	obj(W_est): 9.9458e+04
#
# Inner iteration 15000
# 	h(W_est): 6.6193e-01
# 	score(W_est): 9.0132e+07
# 	obj(W_est): 9.0133e+04
#
# Inner iteration 16000
# 	h(W_est): 6.6157e-01
# 	score(W_est): 9.0913e+07
# 	obj(W_est): 9.0913e+04
#
# Inner iteration 17000
# 	h(W_est): 6.6122e-01
# 	score(W_est): 9.8434e+07
# 	obj(W_est): 9.8435e+04
#
# Inner iteration 18000
# 	h(W_est): 6.6089e-01
# 	score(W_est): 1.0887e+08
# 	obj(W_est): 1.0887e+05
#
# Inner iteration 19000
# 	h(W_est): 6.6057e-01
# 	score(W_est): 1.1194e+08
# 	obj(W_est): 1.1194e+05
#
# Inner iteration 20000
# 	h(W_est): 6.6026e-01
# 	score(W_est): 1.0418e+08
# 	obj(W_est): 1.0418e+05
#
# Inner iteration 21000
# 	h(W_est): 6.5996e-01
# 	score(W_est): 9.3626e+07
# 	obj(W_est): 9.3626e+04
#
# Inner iteration 22000
# 	h(W_est): 6.5966e-01
# 	score(W_est): 9.0407e+07
# 	obj(W_est): 9.0408e+04
#
# Inner iteration 23000
# 	h(W_est): 6.5938e-01
# 	score(W_est): 9.7121e+07
# 	obj(W_est): 9.7121e+04
#
# Inner iteration 24000
# 	h(W_est): 6.5909e-01
# 	score(W_est): 1.0776e+08
# 	obj(W_est): 1.0776e+05
#
# Inner iteration 25000
# 	h(W_est): 6.5881e-01
# 	score(W_est): 1.1200e+08
# 	obj(W_est): 1.1200e+05
#
# Inner iteration 26000
# 	h(W_est): 6.5853e-01
# 	score(W_est): 1.0520e+08
# 	obj(W_est): 1.0520e+05
#
# Inner iteration 27000
# 	h(W_est): 6.5826e-01
# 	score(W_est): 9.4385e+07
# 	obj(W_est): 9.4386e+04
#
# Inner iteration 28000
# 	h(W_est): 6.5799e-01
# 	score(W_est): 9.0073e+07
# 	obj(W_est): 9.0074e+04
#
# Inner iteration 29000
# 	h(W_est): 6.5772e-01
# 	score(W_est): 9.5862e+07
# 	obj(W_est): 9.5862e+04
#
# Inner iteration 30000
# 	h(W_est): 6.5745e-01
# 	score(W_est): 1.0656e+08
# 	obj(W_est): 1.0656e+05
#
# Iteration -- 5:
#
#
# Minimize with -- mu:0.00010000000000000003 -- lr: 0.0003 -- s: 0.9999999999999999 -- l1: 0.02 for 60000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 7.3064e-01
# 	score(W_est): 2.0899e+08
# 	obj(W_est): 2.0899e+04
#
# Inner iteration 2000
# 	h(W_est): 7.3046e-01
# 	score(W_est): 1.0010e+07
# 	obj(W_est): 1.0018e+03
#
# Inner iteration 3000
# 	h(W_est): 7.3014e-01
# 	score(W_est): 1.0000e+07
# 	obj(W_est): 1.0007e+03
#
# Inner iteration 4000
# 	h(W_est): 7.2963e-01
# 	score(W_est): 9.9961e+06
# 	obj(W_est): 1.0003e+03
#
# Inner iteration 5000
# 	h(W_est): 7.2882e-01
# 	score(W_est): 9.9898e+06
# 	obj(W_est): 9.9971e+02
#
# Inner iteration 6000
# 	h(W_est): 7.2759e-01
# 	score(W_est): 9.9801e+06
# 	obj(W_est): 9.9874e+02
#
# Inner iteration 7000
# 	h(W_est): 7.2573e-01
# 	score(W_est): 9.9655e+06
# 	obj(W_est): 9.9728e+02
#
# Inner iteration 8000
# 	h(W_est): 7.2291e-01
# 	score(W_est): 9.9439e+06
# 	obj(W_est): 9.9512e+02
#
# Inner iteration 9000
# 	h(W_est): 7.2053e-01
# 	score(W_est): 1.3367e+07
# 	obj(W_est): 1.3374e+03
#
# Inner iteration 10000
# 	h(W_est): 7.1795e-01
# 	score(W_est): 1.0584e+08
# 	obj(W_est): 1.0584e+04
#
# Inner iteration 11000
# 	h(W_est): 7.1506e-01
# 	score(W_est): 8.9128e+07
# 	obj(W_est): 8.9135e+03
#
# Inner iteration 12000
# 	h(W_est): 7.1197e-01
# 	score(W_est): 1.0475e+08
# 	obj(W_est): 1.0476e+04
#
# Inner iteration 13000
# 	h(W_est): 7.0896e-01
# 	score(W_est): 9.2722e+07
# 	obj(W_est): 9.2729e+03
#
# Inner iteration 14000
# 	h(W_est): 7.0609e-01
# 	score(W_est): 1.0879e+08
# 	obj(W_est): 1.0880e+04
#
# Inner iteration 15000
# 	h(W_est): 7.0335e-01
# 	score(W_est): 1.0756e+08
# 	obj(W_est): 1.0757e+04
#
# Inner iteration 16000
# 	h(W_est): 7.0075e-01
# 	score(W_est): 9.9488e+07
# 	obj(W_est): 9.9495e+03
#
# Inner iteration 17000
# 	h(W_est): 6.9827e-01
# 	score(W_est): 9.2312e+07
# 	obj(W_est): 9.2319e+03
#
# Inner iteration 18000
# 	h(W_est): 6.9591e-01
# 	score(W_est): 9.3137e+07
# 	obj(W_est): 9.3144e+03
#
# Inner iteration 19000
# 	h(W_est): 6.9366e-01
# 	score(W_est): 1.0114e+08
# 	obj(W_est): 1.0114e+04
#
# Inner iteration 20000
# 	h(W_est): 6.9151e-01
# 	score(W_est): 1.0836e+08
# 	obj(W_est): 1.0837e+04
#
# Inner iteration 21000
# 	h(W_est): 6.8947e-01
# 	score(W_est): 1.0796e+08
# 	obj(W_est): 1.0797e+04
#
# Inner iteration 22000
# 	h(W_est): 6.8752e-01
# 	score(W_est): 1.0033e+08
# 	obj(W_est): 1.0033e+04
#
# Inner iteration 23000
# 	h(W_est): 6.8565e-01
# 	score(W_est): 9.2622e+07
# 	obj(W_est): 9.2629e+03
#
# Inner iteration 24000
# 	h(W_est): 6.8388e-01
# 	score(W_est): 9.2441e+07
# 	obj(W_est): 9.2448e+03
#
# Inner iteration 25000
# 	h(W_est): 6.8218e-01
# 	score(W_est): 9.9977e+07
# 	obj(W_est): 9.9984e+03
#
# Inner iteration 26000
# 	h(W_est): 6.8056e-01
# 	score(W_est): 1.0771e+08
# 	obj(W_est): 1.0772e+04
#
# Inner iteration 27000
# 	h(W_est): 6.7901e-01
# 	score(W_est): 1.0828e+08
# 	obj(W_est): 1.0828e+04
#
# Inner iteration 28000
# 	h(W_est): 6.7753e-01
# 	score(W_est): 1.0117e+08
# 	obj(W_est): 1.0117e+04
#
# Inner iteration 29000
# 	h(W_est): 6.7612e-01
# 	score(W_est): 9.3033e+07
# 	obj(W_est): 9.3040e+03
#
# Inner iteration 30000
# 	h(W_est): 6.7477e-01
# 	score(W_est): 9.1849e+07
# 	obj(W_est): 9.1855e+03
#
# Inner iteration 31000
# 	h(W_est): 6.7348e-01
# 	score(W_est): 9.8821e+07
# 	obj(W_est): 9.8828e+03
#
# Inner iteration 32000
# 	h(W_est): 6.7224e-01
# 	score(W_est): 1.0697e+08
# 	obj(W_est): 1.0698e+04
#
# Inner iteration 33000
# 	h(W_est): 6.7106e-01
# 	score(W_est): 1.0849e+08
# 	obj(W_est): 1.0850e+04
#
# Inner iteration 34000
# 	h(W_est): 6.6992e-01
# 	score(W_est): 1.0200e+08
# 	obj(W_est): 1.0200e+04
#
# Inner iteration 35000
# 	h(W_est): 6.6884e-01
# 	score(W_est): 9.3536e+07
# 	obj(W_est): 9.3542e+03
#
# Inner iteration 36000
# 	h(W_est): 6.6781e-01
# 	score(W_est): 9.1364e+07
# 	obj(W_est): 9.1371e+03
#
# Inner iteration 37000
# 	h(W_est): 6.6681e-01
# 	score(W_est): 9.7683e+07
# 	obj(W_est): 9.7690e+03
#
# Inner iteration 38000
# 	h(W_est): 6.6587e-01
# 	score(W_est): 1.0615e+08
# 	obj(W_est): 1.0616e+04
#
# Inner iteration 39000
# 	h(W_est): 6.6495e-01
# 	score(W_est): 1.0861e+08
# 	obj(W_est): 1.0861e+04
#
# Inner iteration 40000
# 	h(W_est): 6.6408e-01
# 	score(W_est): 1.0280e+08
# 	obj(W_est): 1.0281e+04
#
# Inner iteration 41000
# 	h(W_est): 6.6324e-01
# 	score(W_est): 9.4122e+07
# 	obj(W_est): 9.4129e+03
#
# Inner iteration 42000
# 	h(W_est): 6.6244e-01
# 	score(W_est): 9.0993e+07
# 	obj(W_est): 9.1000e+03
#
# Inner iteration 43000
# 	h(W_est): 6.6167e-01
# 	score(W_est): 9.6574e+07
# 	obj(W_est): 9.6581e+03
#
# Inner iteration 44000
# 	h(W_est): 6.6093e-01
# 	score(W_est): 1.0525e+08
# 	obj(W_est): 1.0526e+04
#
# Inner iteration 45000
# 	h(W_est): 6.6022e-01
# 	score(W_est): 1.0862e+08
# 	obj(W_est): 1.0862e+04
#
# Inner iteration 46000
# 	h(W_est): 6.5954e-01
# 	score(W_est): 1.0357e+08
# 	obj(W_est): 1.0358e+04
#
# Inner iteration 47000
# 	h(W_est): 6.5889e-01
# 	score(W_est): 9.4783e+07
# 	obj(W_est): 9.4790e+03
#
# Inner iteration 48000
# 	h(W_est): 6.5826e-01
# 	score(W_est): 9.0738e+07
# 	obj(W_est): 9.0745e+03
#
# Inner iteration 49000
# 	h(W_est): 6.5765e-01
# 	score(W_est): 9.5507e+07
# 	obj(W_est): 9.5514e+03
#
# Inner iteration 50000
# 	h(W_est): 6.5708e-01
# 	score(W_est): 1.0429e+08
# 	obj(W_est): 1.0429e+04
#
# Inner iteration 51000
# 	h(W_est): 6.5652e-01
# 	score(W_est): 1.0852e+08
# 	obj(W_est): 1.0853e+04
#
# Inner iteration 52000
# 	h(W_est): 6.5598e-01
# 	score(W_est): 1.0429e+08
# 	obj(W_est): 1.0430e+04
#
# Inner iteration 53000
# 	h(W_est): 6.5547e-01
# 	score(W_est): 9.5507e+07
# 	obj(W_est): 9.5514e+03
#
# Inner iteration 54000
# 	h(W_est): 6.5497e-01
# 	score(W_est): 9.0600e+07
# 	obj(W_est): 9.0606e+03
#
# Inner iteration 55000
# 	h(W_est): 6.5449e-01
# 	score(W_est): 9.4495e+07
# 	obj(W_est): 9.4501e+03
#
# Inner iteration 56000
# 	h(W_est): 6.5403e-01
# 	score(W_est): 1.0326e+08
# 	obj(W_est): 1.0327e+04
#
# Inner iteration 57000
# 	h(W_est): 6.5359e-01
# 	score(W_est): 1.0832e+08
# 	obj(W_est): 1.0833e+04
#
# Inner iteration 58000
# 	h(W_est): 6.5316e-01
# 	score(W_est): 1.0496e+08
# 	obj(W_est): 1.0497e+04
#
# Inner iteration 59000
# 	h(W_est): 6.5275e-01
# 	score(W_est): 9.6284e+07
# 	obj(W_est): 9.6290e+03
#
# Inner iteration 60000
# 	h(W_est): 6.5236e-01
# 	score(W_est): 9.0578e+07
# 	obj(W_est): 9.0585e+03
# {'fdr': 0.06666666666666667, 'tpr': 0.4359281437125748, 'fpr': 0.52, 'shd': 992, 'nnz': 780}

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 20, 100
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2', verbose=True) # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# Iteration -- 1:
#
#
# Minimize with -- mu:1.0 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 3.0539e-01
# 	score(W_est): 1.2271e+04
# 	obj(W_est): 1.2271e+04
#
# Inner iteration 2000
# 	h(W_est): 4.6857e-01
# 	score(W_est): 2.5736e+02
# 	obj(W_est): 2.5854e+02
#
# Inner iteration 3000
# 	h(W_est): 5.8020e-01
# 	score(W_est): 1.0665e+02
# 	obj(W_est): 1.0802e+02
#
# Inner iteration 4000
# 	h(W_est): 6.7507e-01
# 	score(W_est): 7.9834e+01
# 	obj(W_est): 8.1375e+01
#
# Inner iteration 5000
# 	h(W_est): 7.3496e-01
# 	score(W_est): 6.0580e+01
# 	obj(W_est): 6.2236e+01
#
# Inner iteration 6000
# 	h(W_est): 7.5536e-01
# 	score(W_est): 4.6666e+01
# 	obj(W_est): 4.8386e+01
#
# Inner iteration 7000
# 	h(W_est): 7.5543e-01
# 	score(W_est): 3.5662e+01
# 	obj(W_est): 3.7415e+01
#
# Inner iteration 8000
# 	h(W_est): 7.5435e-01
# 	score(W_est): 2.6359e+01
# 	obj(W_est): 2.8151e+01
#
# Inner iteration 9000
# 	h(W_est): 7.6214e-01
# 	score(W_est): 1.8387e+01
# 	obj(W_est): 2.0223e+01
#
# Inner iteration 10000
# 	h(W_est): 7.8827e-01
# 	score(W_est): 1.2135e+01
# 	obj(W_est): 1.4031e+01
#
# Inner iteration 11000
# 	h(W_est): 8.4062e-01
# 	score(W_est): 8.0632e+00
# 	obj(W_est): 1.0039e+01
#
# Inner iteration 12000
# 	h(W_est): 9.1229e-01
# 	score(W_est): 5.8307e+00
# 	obj(W_est): 7.8987e+00
#
# Inner iteration 13000
# 	h(W_est): 9.9713e-01
# 	score(W_est): 4.5477e+00
# 	obj(W_est): 6.7063e+00
#
# Inner iteration 14000
# 	h(W_est): 1.0773e+00
# 	score(W_est): 3.6880e+00
# 	obj(W_est): 5.9267e+00
#
# Inner iteration 15000
# 	h(W_est): 1.1366e+00
# 	score(W_est): 3.0652e+00
# 	obj(W_est): 5.3583e+00
#
# Inner iteration 16000
# 	h(W_est): 1.1729e+00
# 	score(W_est): 2.5870e+00
# 	obj(W_est): 4.9066e+00
#
# Inner iteration 17000
# 	h(W_est): 1.1926e+00
# 	score(W_est): 2.2363e+00
# 	obj(W_est): 4.5623e+00
#
# Inner iteration 18000
# 	h(W_est): 1.2097e+00
# 	score(W_est): 2.0040e+00
# 	obj(W_est): 4.3296e+00
#
# Inner iteration 19000
# 	h(W_est): 1.2231e+00
# 	score(W_est): 1.8633e+00
# 	obj(W_est): 4.1837e+00
#
# Inner iteration 20000
# 	h(W_est): 1.2338e+00
# 	score(W_est): 1.7756e+00
# 	obj(W_est): 4.0894e+00
#
# Inner iteration 21000
# 	h(W_est): 1.2417e+00
# 	score(W_est): 1.7215e+00
# 	obj(W_est): 4.0289e+00
#
# Inner iteration 22000
# 	h(W_est): 1.2429e+00
# 	score(W_est): 1.6935e+00
# 	obj(W_est): 3.9953e+00
#
# Inner iteration 23000
# 	h(W_est): 1.2385e+00
# 	score(W_est): 1.6768e+00
# 	obj(W_est): 3.9700e+00
#
# Inner iteration 24000
# 	h(W_est): 1.2295e+00
# 	score(W_est): 1.6674e+00
# 	obj(W_est): 3.9506e+00
#
# Inner iteration 25000
# 	h(W_est): 1.2186e+00
# 	score(W_est): 1.6652e+00
# 	obj(W_est): 3.9370e+00
#
# Inner iteration 26000
# 	h(W_est): 1.2061e+00
# 	score(W_est): 1.6672e+00
# 	obj(W_est): 3.9303e+00
#
# Inner iteration 27000
# 	h(W_est): 1.1981e+00
# 	score(W_est): 1.6695e+00
# 	obj(W_est): 3.9282e+00
#
# Inner iteration 28000
# 	h(W_est): 1.1936e+00
# 	score(W_est): 1.6712e+00
# 	obj(W_est): 3.9276e+00
#
# Inner iteration 29000
# 	h(W_est): 1.1912e+00
# 	score(W_est): 1.6722e+00
# 	obj(W_est): 3.9274e+00
#
# Inner iteration 30000
# 	h(W_est): 1.1898e+00
# 	score(W_est): 1.6728e+00
# 	obj(W_est): 3.9273e+00
#
# Iteration -- 2:
#
#
# Minimize with -- mu:0.1 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 5.5248e-01
# 	score(W_est): 3.0475e+00
# 	obj(W_est): 9.7048e-01
#
# Inner iteration 2000
# 	h(W_est): 3.4801e-01
# 	score(W_est): 3.4795e+00
# 	obj(W_est): 8.2385e-01
#
# Inner iteration 3000
# 	h(W_est): 2.4278e-01
# 	score(W_est): 3.7239e+00
# 	obj(W_est): 7.5383e-01
#
# Inner iteration 4000
# 	h(W_est): 1.9173e-01
# 	score(W_est): 3.8845e+00
# 	obj(W_est): 7.2541e-01
#
# Inner iteration 5000
# 	h(W_est): 1.7019e-01
# 	score(W_est): 3.9682e+00
# 	obj(W_est): 7.1535e-01
#
# Inner iteration 6000
# 	h(W_est): 1.6073e-01
# 	score(W_est): 4.0005e+00
# 	obj(W_est): 7.1082e-01
#
# Inner iteration 7000
# 	h(W_est): 1.5529e-01
# 	score(W_est): 4.0173e+00
# 	obj(W_est): 7.0819e-01
#
# Inner iteration 8000
# 	h(W_est): 1.5235e-01
# 	score(W_est): 4.0292e+00
# 	obj(W_est): 7.0712e-01
#
# Inner iteration 9000
# 	h(W_est): 1.5120e-01
# 	score(W_est): 4.0362e+00
# 	obj(W_est): 7.0688e-01
#
# Inner iteration 10000
# 	h(W_est): 1.5080e-01
# 	score(W_est): 4.0393e+00
# 	obj(W_est): 7.0682e-01
#
# Inner iteration 11000
# 	h(W_est): 1.5065e-01
# 	score(W_est): 4.0407e+00
# 	obj(W_est): 7.0681e-01
#
# Inner iteration 12000
# 	h(W_est): 1.5059e-01
# 	score(W_est): 4.0413e+00
# 	obj(W_est): 7.0681e-01
#
# Inner iteration 13000
# 	h(W_est): 1.5057e-01
# 	score(W_est): 4.0415e+00
# 	obj(W_est): 7.0681e-01
#
# Iteration -- 3:
#
#
# Minimize with -- mu:0.010000000000000002 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 3.9142e-02
# 	score(W_est): 6.5422e+00
# 	obj(W_est): 1.2104e-01
#
# Inner iteration 2000
# 	h(W_est): 2.3557e-02
# 	score(W_est): 6.9041e+00
# 	obj(W_est): 1.1044e-01
#
# Inner iteration 3000
# 	h(W_est): 1.7465e-02
# 	score(W_est): 7.0389e+00
# 	obj(W_est): 1.0658e-01
#
# Inner iteration 4000
# 	h(W_est): 1.4219e-02
# 	score(W_est): 7.1089e+00
# 	obj(W_est): 1.0456e-01
#
# Inner iteration 5000
# 	h(W_est): 1.2769e-02
# 	score(W_est): 7.1381e+00
# 	obj(W_est): 1.0363e-01
#
# Inner iteration 6000
# 	h(W_est): 1.2289e-02
# 	score(W_est): 7.1338e+00
# 	obj(W_est): 1.0321e-01
#
# Inner iteration 7000
# 	h(W_est): 1.2113e-02
# 	score(W_est): 7.1216e+00
# 	obj(W_est): 1.0299e-01
#
# Inner iteration 8000
# 	h(W_est): 1.2087e-02
# 	score(W_est): 7.1132e+00
# 	obj(W_est): 1.0289e-01
#
# Inner iteration 9000
# 	h(W_est): 1.1887e-02
# 	score(W_est): 7.1160e+00
# 	obj(W_est): 1.0273e-01
#
# Inner iteration 10000
# 	h(W_est): 1.1885e-02
# 	score(W_est): 7.1152e+00
# 	obj(W_est): 1.0273e-01
#
# Inner iteration 11000
# 	h(W_est): 1.1884e-02
# 	score(W_est): 7.1153e+00
# 	obj(W_est): 1.0273e-01
#
# Iteration -- 4:
#
#
# Minimize with -- mu:0.0010000000000000002 -- lr: 0.0003 -- s: 1.0999999999999999 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 2.3133e-03
# 	score(W_est): 8.8600e+00
# 	obj(W_est): 1.3245e-02
#
# Inner iteration 2000
# 	h(W_est): 1.2906e-03
# 	score(W_est): 9.2022e+00
# 	obj(W_est): 1.2648e-02
#
# Inner iteration 3000
# 	h(W_est): 9.3990e-04
# 	score(W_est): 9.3026e+00
# 	obj(W_est): 1.2438e-02
#
# Inner iteration 4000
# 	h(W_est): 7.1541e-04
# 	score(W_est): 9.3625e+00
# 	obj(W_est): 1.2293e-02
#
# Inner iteration 5000
# 	h(W_est): 6.4363e-04
# 	score(W_est): 9.3579e+00
# 	obj(W_est): 1.2216e-02
#
# Inner iteration 6000
# 	h(W_est): 6.0582e-04
# 	score(W_est): 9.3580e+00
# 	obj(W_est): 1.2170e-02
#
# Inner iteration 7000
# 	h(W_est): 5.8744e-04
# 	score(W_est): 9.3555e+00
# 	obj(W_est): 1.2140e-02
#
# Inner iteration 8000
# 	h(W_est): 5.7563e-04
# 	score(W_est): 9.3557e+00
# 	obj(W_est): 1.2122e-02
#
# Inner iteration 9000
# 	h(W_est): 5.6929e-04
# 	score(W_est): 9.3549e+00
# 	obj(W_est): 1.2111e-02
#
# Inner iteration 10000
# 	h(W_est): 5.6661e-04
# 	score(W_est): 9.3533e+00
# 	obj(W_est): 1.2104e-02
#
# Inner iteration 11000
# 	h(W_est): 5.6343e-04
# 	score(W_est): 9.3537e+00
# 	obj(W_est): 1.2099e-02
#
# Inner iteration 12000
# 	h(W_est): 5.6249e-04
# 	score(W_est): 9.3526e+00
# 	obj(W_est): 1.2096e-02
#
# Inner iteration 13000
# 	h(W_est): 5.5945e-04
# 	score(W_est): 9.3541e+00
# 	obj(W_est): 1.2094e-02
#
# Inner iteration 14000
# 	h(W_est): 5.6012e-04
# 	score(W_est): 9.3521e+00
# 	obj(W_est): 1.2092e-02
#
# Inner iteration 15000
# 	h(W_est): 5.5978e-04
# 	score(W_est): 9.3516e+00
# 	obj(W_est): 1.2091e-02
#
# Inner iteration 16000
# 	h(W_est): 5.5918e-04
# 	score(W_est): 9.3514e+00
# 	obj(W_est): 1.2091e-02
#
# Inner iteration 17000
# 	h(W_est): 5.5839e-04
# 	score(W_est): 9.3517e+00
# 	obj(W_est): 1.2090e-02
#
# Inner iteration 18000
# 	h(W_est): 5.5779e-04
# 	score(W_est): 9.3519e+00
# 	obj(W_est): 1.2090e-02
#
# Inner iteration 19000
# 	h(W_est): 5.5741e-04
# 	score(W_est): 9.3520e+00
# 	obj(W_est): 1.2090e-02
#
# Inner iteration 20000
# 	h(W_est): 5.5726e-04
# 	score(W_est): 9.3519e+00
# 	obj(W_est): 1.2090e-02
#
# Inner iteration 21000
# 	h(W_est): 5.5636e-04
# 	score(W_est): 9.3526e+00
# 	obj(W_est): 1.2089e-02
#
# Inner iteration 22000
# 	h(W_est): 5.5610e-04
# 	score(W_est): 9.3527e+00
# 	obj(W_est): 1.2089e-02
#
# Inner iteration 23000
# 	h(W_est): 5.5564e-04
# 	score(W_est): 9.3531e+00
# 	obj(W_est): 1.2089e-02
#
# Inner iteration 24000
# 	h(W_est): 5.5707e-04
# 	score(W_est): 9.3515e+00
# 	obj(W_est): 1.2089e-02
#
# Inner iteration 25000
# 	h(W_est): 5.5591e-04
# 	score(W_est): 9.3526e+00
# 	obj(W_est): 1.2089e-02
#
# Inner iteration 26000
# 	h(W_est): 5.5721e-04
# 	score(W_est): 9.3513e+00
# 	obj(W_est): 1.2089e-02
#
# Inner iteration 27000
# 	h(W_est): 5.5697e-04
# 	score(W_est): 9.3515e+00
# 	obj(W_est): 1.2089e-02
#
# Inner iteration 28000
# 	h(W_est): 5.5675e-04
# 	score(W_est): 9.3517e+00
# 	obj(W_est): 1.2089e-02
#
# Iteration -- 5:
#
#
# Minimize with -- mu:0.00010000000000000003 -- lr: 0.0003 -- s: 0.9999999999999999 -- l1: 0.02 for 60000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 2.3982e-05
# 	score(W_est): 1.0873e+01
# 	obj(W_est): 1.3347e-03
#
# Inner iteration 2000
# 	h(W_est): 1.7875e-05
# 	score(W_est): 1.0893e+01
# 	obj(W_est): 1.3314e-03
#
# Inner iteration 3000
# 	h(W_est): 1.4667e-05
# 	score(W_est): 1.0902e+01
# 	obj(W_est): 1.3293e-03
#
# Inner iteration 4000
# 	h(W_est): 1.3163e-05
# 	score(W_est): 1.0902e+01
# 	obj(W_est): 1.3279e-03
#
# Inner iteration 5000
# 	h(W_est): 1.2041e-05
# 	score(W_est): 1.0904e+01
# 	obj(W_est): 1.3267e-03
#
# Inner iteration 6000
# 	h(W_est): 1.1126e-05
# 	score(W_est): 1.0906e+01
# 	obj(W_est): 1.3259e-03
#
# Inner iteration 7000
# 	h(W_est): 1.0611e-05
# 	score(W_est): 1.0909e+01
# 	obj(W_est): 1.3255e-03
#
# Inner iteration 8000
# 	h(W_est): 1.0252e-05
# 	score(W_est): 1.0910e+01
# 	obj(W_est): 1.3253e-03
#
# Inner iteration 9000
# 	h(W_est): 1.0424e-05
# 	score(W_est): 1.0907e+01
# 	obj(W_est): 1.3251e-03
#
# Inner iteration 10000
# 	h(W_est): 1.0274e-05
# 	score(W_est): 1.0908e+01
# 	obj(W_est): 1.3250e-03
#
# Inner iteration 11000
# 	h(W_est): 1.0398e-05
# 	score(W_est): 1.0905e+01
# 	obj(W_est): 1.3248e-03
#
# Inner iteration 12000
# 	h(W_est): 1.0129e-05
# 	score(W_est): 1.0907e+01
# 	obj(W_est): 1.3246e-03
#
# Inner iteration 13000
# 	h(W_est): 1.0579e-05
# 	score(W_est): 1.0903e+01
# 	obj(W_est): 1.3243e-03
#
# Inner iteration 14000
# 	h(W_est): 1.0363e-05
# 	score(W_est): 1.0906e+01
# 	obj(W_est): 1.3241e-03
#
# Inner iteration 15000
# 	h(W_est): 1.0589e-05
# 	score(W_est): 1.0905e+01
# 	obj(W_est): 1.3240e-03
#
# Inner iteration 16000
# 	h(W_est): 1.0646e-05
# 	score(W_est): 1.0905e+01
# 	obj(W_est): 1.3240e-03
#
# Inner iteration 17000
# 	h(W_est): 1.0583e-05
# 	score(W_est): 1.0906e+01
# 	obj(W_est): 1.3240e-03
#
# Inner iteration 18000
# 	h(W_est): 1.0625e-05
# 	score(W_est): 1.0906e+01
# 	obj(W_est): 1.3240e-03
#
# Inner iteration 19000
# 	h(W_est): 1.0620e-05
# 	score(W_est): 1.0907e+01
# 	obj(W_est): 1.3240e-03
# {'fdr': 0.07142857142857142, 'tpr': 0.91, 'fpr': 0.07777777777777778, 'shd': 13, 'nnz': 98}

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 60, 240
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2', verbose=True) # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 utils_dagma.set_random_seed(1)
#       2 # Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
#       3 # number of samples n = 500
#       4 n, d, s0 = 2000, 60, 240
#
# NameError: name 'utils_dagma' is not defined

# %%
utils_dagma.set_random_seed(1)
# Create an Erdos-Renyi DAG of 20 nodes and 20 edges in expectation with Gaussian noise
# number of samples n = 500
n, d, s0 = 2000, 20, 150
graph_type, sem_type = 'ER', 'gauss'

B_true = utils_dagma.simulate_dag(d, s0, graph_type)
W_true = utils_dagma.simulate_parameter(B_true)
X = utils_dagma.simulate_linear_sem(W_true, n, sem_type)

model = linear.DagmaLinear(loss_type='l2', verbose=True) # create a linear model with least squares loss
W_est = model.fit(None, X, lambda1=0.02) # fit the model with L1 reg. (coeff. 0.02)
acc = utils_dagma.count_accuracy(B_true, W_est != 0) # compute metrics of estimated adjacency matrix W_est with ground-truth
print(acc)
# Out:
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# Iteration -- 1:
#
#
# Minimize with -- mu:1.0 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 2.7712e-01
# 	score(W_est): 2.0051e+03
# 	obj(W_est): 2.0059e+03
#
# Inner iteration 2000
# 	h(W_est): 5.1847e-01
# 	score(W_est): 5.1632e+02
# 	obj(W_est): 5.1745e+02
#
# Inner iteration 3000
# 	h(W_est): 7.9022e-01
# 	score(W_est): 2.5683e+02
# 	obj(W_est): 2.5832e+02
#
# Inner iteration 4000
# 	h(W_est): 1.0986e+00
# 	score(W_est): 1.3021e+02
# 	obj(W_est): 1.3207e+02
#
# Inner iteration 5000
# 	h(W_est): 1.3814e+00
# 	score(W_est): 6.7249e+01
# 	obj(W_est): 6.9457e+01
#
# Inner iteration 6000
# 	h(W_est): 1.5217e+00
# 	score(W_est): 3.6445e+01
# 	obj(W_est): 3.8837e+01
#
# Inner iteration 7000
# 	h(W_est): 1.5495e+00
# 	score(W_est): 2.2310e+01
# 	obj(W_est): 2.4763e+01
#
# Inner iteration 8000
# 	h(W_est): 1.5527e+00
# 	score(W_est): 1.5715e+01
# 	obj(W_est): 1.8192e+01
#
# Inner iteration 9000
# 	h(W_est): 1.5539e+00
# 	score(W_est): 1.1882e+01
# 	obj(W_est): 1.4373e+01
#
# Inner iteration 10000
# 	h(W_est): 1.5586e+00
# 	score(W_est): 8.8767e+00
# 	obj(W_est): 1.1389e+01
#
# Inner iteration 11000
# 	h(W_est): 1.5720e+00
# 	score(W_est): 6.3721e+00
# 	obj(W_est): 8.9142e+00
#
# Inner iteration 12000
# 	h(W_est): 1.5856e+00
# 	score(W_est): 4.5709e+00
# 	obj(W_est): 7.1399e+00
#
# Inner iteration 13000
# 	h(W_est): 1.5827e+00
# 	score(W_est): 3.4007e+00
# 	obj(W_est): 5.9758e+00
#
# Inner iteration 14000
# 	h(W_est): 1.5509e+00
# 	score(W_est): 2.6340e+00
# 	obj(W_est): 5.1760e+00
#
# Inner iteration 15000
# 	h(W_est): 1.4949e+00
# 	score(W_est): 2.1575e+00
# 	obj(W_est): 4.6376e+00
#
# Inner iteration 16000
# 	h(W_est): 1.4275e+00
# 	score(W_est): 1.8966e+00
# 	obj(W_est): 4.3050e+00
#
# Inner iteration 17000
# 	h(W_est): 1.3628e+00
# 	score(W_est): 1.7376e+00
# 	obj(W_est): 4.0823e+00
#
# Inner iteration 18000
# 	h(W_est): 1.3096e+00
# 	score(W_est): 1.6258e+00
# 	obj(W_est): 3.9236e+00
#
# Inner iteration 19000
# 	h(W_est): 1.2820e+00
# 	score(W_est): 1.5422e+00
# 	obj(W_est): 3.8194e+00
#
# Inner iteration 20000
# 	h(W_est): 1.2671e+00
# 	score(W_est): 1.4853e+00
# 	obj(W_est): 3.7541e+00
#
# Inner iteration 21000
# 	h(W_est): 1.2485e+00
# 	score(W_est): 1.4555e+00
# 	obj(W_est): 3.7088e+00
#
# Inner iteration 22000
# 	h(W_est): 1.2261e+00
# 	score(W_est): 1.4392e+00
# 	obj(W_est): 3.6722e+00
#
# Inner iteration 23000
# 	h(W_est): 1.2001e+00
# 	score(W_est): 1.4336e+00
# 	obj(W_est): 3.6440e+00
#
# Inner iteration 24000
# 	h(W_est): 1.1762e+00
# 	score(W_est): 1.4328e+00
# 	obj(W_est): 3.6241e+00
#
# Inner iteration 25000
# 	h(W_est): 1.1541e+00
# 	score(W_est): 1.4395e+00
# 	obj(W_est): 3.6140e+00
#
# Inner iteration 26000
# 	h(W_est): 1.1420e+00
# 	score(W_est): 1.4457e+00
# 	obj(W_est): 3.6107e+00
#
# Inner iteration 27000
# 	h(W_est): 1.1363e+00
# 	score(W_est): 1.4495e+00
# 	obj(W_est): 3.6094e+00
#
# Inner iteration 28000
# 	h(W_est): 1.1333e+00
# 	score(W_est): 1.4517e+00
# 	obj(W_est): 3.6087e+00
#
# Inner iteration 29000
# 	h(W_est): 1.1315e+00
# 	score(W_est): 1.4532e+00
# 	obj(W_est): 3.6083e+00
#
# Inner iteration 30000
# 	h(W_est): 1.1303e+00
# 	score(W_est): 1.4542e+00
# 	obj(W_est): 3.6081e+00
#
# Iteration -- 2:
#
#
# Minimize with -- mu:0.1 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 6.3889e-01
# 	score(W_est): 2.5337e+00
# 	obj(W_est): 9.9795e-01
#
# Inner iteration 2000
# 	h(W_est): 4.3709e-01
# 	score(W_est): 3.0068e+00
# 	obj(W_est): 8.5518e-01
#
# Inner iteration 3000
# 	h(W_est): 3.4309e-01
# 	score(W_est): 3.2122e+00
# 	obj(W_est): 7.9140e-01
#
# Inner iteration 4000
# 	h(W_est): 2.8852e-01
# 	score(W_est): 3.3405e+00
# 	obj(W_est): 7.5758e-01
#
# Inner iteration 5000
# 	h(W_est): 2.5522e-01
# 	score(W_est): 3.4148e+00
# 	obj(W_est): 7.3925e-01
#
# Inner iteration 6000
# 	h(W_est): 2.3467e-01
# 	score(W_est): 3.4618e+00
# 	obj(W_est): 7.3010e-01
#
# Inner iteration 7000
# 	h(W_est): 2.2281e-01
# 	score(W_est): 3.4857e+00
# 	obj(W_est): 7.2587e-01
#
# Inner iteration 8000
# 	h(W_est): 2.1687e-01
# 	score(W_est): 3.4992e+00
# 	obj(W_est): 7.2445e-01
#
# Inner iteration 9000
# 	h(W_est): 2.1443e-01
# 	score(W_est): 3.5061e+00
# 	obj(W_est): 7.2408e-01
#
# Inner iteration 10000
# 	h(W_est): 2.1345e-01
# 	score(W_est): 3.5095e+00
# 	obj(W_est): 7.2400e-01
#
# Inner iteration 11000
# 	h(W_est): 2.1303e-01
# 	score(W_est): 3.5112e+00
# 	obj(W_est): 7.2397e-01
#
# Inner iteration 12000
# 	h(W_est): 2.1285e-01
# 	score(W_est): 3.5119e+00
# 	obj(W_est): 7.2397e-01
#
# Inner iteration 13000
# 	h(W_est): 2.1274e-01
# 	score(W_est): 3.5122e+00
# 	obj(W_est): 7.2396e-01
#
# Inner iteration 14000
# 	h(W_est): 2.1270e-01
# 	score(W_est): 3.5123e+00
# 	obj(W_est): 7.2396e-01
#
# Inner iteration 15000
# 	h(W_est): 2.1267e-01
# 	score(W_est): 3.5124e+00
# 	obj(W_est): 7.2396e-01
#
# Iteration -- 3:
#
#
# Minimize with -- mu:0.010000000000000002 -- lr: 0.0003 -- s: 1.0 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 8.2261e-02
# 	score(W_est): 6.8565e+00
# 	obj(W_est): 1.6864e-01
#
# Inner iteration 2000
# 	h(W_est): 5.8311e-02
# 	score(W_est): 7.1963e+00
# 	obj(W_est): 1.5025e-01
#
# Inner iteration 3000
# 	h(W_est): 4.1333e-02
# 	score(W_est): 7.5219e+00
# 	obj(W_est): 1.3862e-01
#
# Inner iteration 4000
# 	h(W_est): 3.0944e-02
# 	score(W_est): 7.7332e+00
# 	obj(W_est): 1.3206e-01
#
# Inner iteration 5000
# 	h(W_est): 2.4271e-02
# 	score(W_est): 7.8491e+00
# 	obj(W_est): 1.2761e-01
#
# Inner iteration 6000
# 	h(W_est): 2.1067e-02
# 	score(W_est): 7.8727e+00
# 	obj(W_est): 1.2517e-01
#
# Inner iteration 7000
# 	h(W_est): 1.9664e-02
# 	score(W_est): 7.9068e+00
# 	obj(W_est): 1.2453e-01
#
# Inner iteration 8000
# 	h(W_est): 1.8933e-02
# 	score(W_est): 7.9296e+00
# 	obj(W_est): 1.2431e-01
#
# Inner iteration 9000
# 	h(W_est): 1.8731e-02
# 	score(W_est): 7.9316e+00
# 	obj(W_est): 1.2421e-01
#
# Inner iteration 10000
# 	h(W_est): 1.8667e-02
# 	score(W_est): 7.9336e+00
# 	obj(W_est): 1.2418e-01
#
# Inner iteration 11000
# 	h(W_est): 1.8640e-02
# 	score(W_est): 7.9354e+00
# 	obj(W_est): 1.2417e-01
#
# Inner iteration 12000
# 	h(W_est): 1.8631e-02
# 	score(W_est): 7.9360e+00
# 	obj(W_est): 1.2417e-01
#
# Inner iteration 13000
# 	h(W_est): 1.8619e-02
# 	score(W_est): 7.9369e+00
# 	obj(W_est): 1.2417e-01
#
# Inner iteration 14000
# 	h(W_est): 1.8613e-02
# 	score(W_est): 7.9373e+00
# 	obj(W_est): 1.2417e-01
#
# Inner iteration 15000
# 	h(W_est): 1.8604e-02
# 	score(W_est): 7.9380e+00
# 	obj(W_est): 1.2416e-01
#
# Inner iteration 16000
# 	h(W_est): 1.8598e-02
# 	score(W_est): 7.9385e+00
# 	obj(W_est): 1.2416e-01
#
# Inner iteration 17000
# 	h(W_est): 1.8595e-02
# 	score(W_est): 7.9386e+00
# 	obj(W_est): 1.2416e-01
#
# Inner iteration 18000
# 	h(W_est): 1.8588e-02
# 	score(W_est): 7.9392e+00
# 	obj(W_est): 1.2416e-01
#
# Inner iteration 19000
# 	h(W_est): 1.8589e-02
# 	score(W_est): 7.9391e+00
# 	obj(W_est): 1.2416e-01
#
# Inner iteration 20000
# 	h(W_est): 1.8583e-02
# 	score(W_est): 7.9396e+00
# 	obj(W_est): 1.2416e-01
#
# Inner iteration 21000
# 	h(W_est): 1.8580e-02
# 	score(W_est): 7.9399e+00
# 	obj(W_est): 1.2416e-01
#
# Inner iteration 22000
# 	h(W_est): 1.8582e-02
# 	score(W_est): 7.9396e+00
# 	obj(W_est): 1.2416e-01
#
# Iteration -- 4:
#
#
# Minimize with -- mu:0.0010000000000000002 -- lr: 0.0003 -- s: 1.0999999999999999 -- l1: 0.02 for 30000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 1.7460e-03
# 	score(W_est): 1.1162e+01
# 	obj(W_est): 1.5654e-02
#
# Inner iteration 2000
# 	h(W_est): 1.0868e-03
# 	score(W_est): 1.1153e+01
# 	obj(W_est): 1.5084e-02
#
# Inner iteration 3000
# 	h(W_est): 7.7250e-04
# 	score(W_est): 1.1150e+01
# 	obj(W_est): 1.4834e-02
#
# Inner iteration 4000
# 	h(W_est): 5.8329e-04
# 	score(W_est): 1.1146e+01
# 	obj(W_est): 1.4683e-02
#
# Inner iteration 5000
# 	h(W_est): 4.6110e-04
# 	score(W_est): 1.1147e+01
# 	obj(W_est): 1.4596e-02
#
# Inner iteration 6000
# 	h(W_est): 3.9193e-04
# 	score(W_est): 1.1158e+01
# 	obj(W_est): 1.4556e-02
#
# Inner iteration 7000
# 	h(W_est): 3.5171e-04
# 	score(W_est): 1.1178e+01
# 	obj(W_est): 1.4543e-02
#
# Inner iteration 8000
# 	h(W_est): 3.3155e-04
# 	score(W_est): 1.1192e+01
# 	obj(W_est): 1.4540e-02
#
# Inner iteration 9000
# 	h(W_est): 3.2113e-04
# 	score(W_est): 1.1200e+01
# 	obj(W_est): 1.4539e-02
#
# Inner iteration 10000
# 	h(W_est): 3.1952e-04
# 	score(W_est): 1.1201e+01
# 	obj(W_est): 1.4538e-02
#
# Inner iteration 11000
# 	h(W_est): 3.1871e-04
# 	score(W_est): 1.1201e+01
# 	obj(W_est): 1.4538e-02
#
# Inner iteration 12000
# 	h(W_est): 3.2097e-04
# 	score(W_est): 1.1198e+01
# 	obj(W_est): 1.4537e-02
#
# Inner iteration 13000
# 	h(W_est): 3.2035e-04
# 	score(W_est): 1.1198e+01
# 	obj(W_est): 1.4537e-02
#
# Inner iteration 14000
# 	h(W_est): 3.1845e-04
# 	score(W_est): 1.1200e+01
# 	obj(W_est): 1.4537e-02
#
# Inner iteration 15000
# 	h(W_est): 3.2045e-04
# 	score(W_est): 1.1198e+01
# 	obj(W_est): 1.4537e-02
#
# Inner iteration 16000
# 	h(W_est): 3.1837e-04
# 	score(W_est): 1.1200e+01
# 	obj(W_est): 1.4537e-02
#
# Inner iteration 17000
# 	h(W_est): 3.1790e-04
# 	score(W_est): 1.1200e+01
# 	obj(W_est): 1.4537e-02
#
# Inner iteration 18000
# 	h(W_est): 3.1773e-04
# 	score(W_est): 1.1200e+01
# 	obj(W_est): 1.4537e-02
#
# Inner iteration 19000
# 	h(W_est): 3.1664e-04
# 	score(W_est): 1.1202e+01
# 	obj(W_est): 1.4537e-02
#
# Inner iteration 20000
# 	h(W_est): 3.2013e-04
# 	score(W_est): 1.1198e+01
# 	obj(W_est): 1.4537e-02
#
# Inner iteration 21000
# 	h(W_est): 3.1896e-04
# 	score(W_est): 1.1199e+01
# 	obj(W_est): 1.4537e-02
#
# Iteration -- 5:
#
#
# Minimize with -- mu:0.00010000000000000003 -- lr: 0.0003 -- s: 0.9999999999999999 -- l1: 0.02 for 60000 max iterations
#
# Inner iteration 1000
# 	h(W_est): 3.3389e-06
# 	score(W_est): 1.1970e+01
# 	obj(W_est): 1.4995e-03
#
# Inner iteration 2000
# 	h(W_est): 2.6843e-06
# 	score(W_est): 1.1859e+01
# 	obj(W_est): 1.4896e-03
#
# Inner iteration 3000
# 	h(W_est): 2.2694e-06
# 	score(W_est): 1.1805e+01
# 	obj(W_est): 1.4852e-03
#
# Inner iteration 4000
# 	h(W_est): 2.0207e-06
# 	score(W_est): 1.1766e+01
# 	obj(W_est): 1.4823e-03
#
# Inner iteration 5000
# 	h(W_est): 1.8357e-06
# 	score(W_est): 1.1733e+01
# 	obj(W_est): 1.4801e-03
#
# Inner iteration 6000
# 	h(W_est): 1.5894e-06
# 	score(W_est): 1.1708e+01
# 	obj(W_est): 1.4784e-03
#
# Inner iteration 7000
# 	h(W_est): 1.6531e-06
# 	score(W_est): 1.1691e+01
# 	obj(W_est): 1.4776e-03
#
# Inner iteration 8000
# 	h(W_est): 1.6535e-06
# 	score(W_est): 1.1683e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 9000
# 	h(W_est): 1.9268e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4773e-03
#
# Inner iteration 10000
# 	h(W_est): 1.5762e-06
# 	score(W_est): 1.1681e+01
# 	obj(W_est): 1.4771e-03
#
# Inner iteration 11000
# 	h(W_est): 1.7503e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 12000
# 	h(W_est): 1.4007e-06
# 	score(W_est): 1.1682e+01
# 	obj(W_est): 1.4771e-03
#
# Inner iteration 13000
# 	h(W_est): 1.7366e-06
# 	score(W_est): 1.1679e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 14000
# 	h(W_est): 1.6978e-06
# 	score(W_est): 1.1679e+01
# 	obj(W_est): 1.4771e-03
#
# Inner iteration 15000
# 	h(W_est): 1.6741e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 16000
# 	h(W_est): 1.5004e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4771e-03
#
# Inner iteration 17000
# 	h(W_est): 1.7242e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 18000
# 	h(W_est): 1.5973e-06
# 	score(W_est): 1.1681e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 19000
# 	h(W_est): 1.8146e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4773e-03
#
# Inner iteration 20000
# 	h(W_est): 1.5627e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4771e-03
#
# Inner iteration 21000
# 	h(W_est): 1.5908e-06
# 	score(W_est): 1.1681e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 22000
# 	h(W_est): 1.6941e-06
# 	score(W_est): 1.1679e+01
# 	obj(W_est): 1.4771e-03
#
# Inner iteration 23000
# 	h(W_est): 1.4756e-06
# 	score(W_est): 1.1681e+01
# 	obj(W_est): 1.4771e-03
#
# Inner iteration 24000
# 	h(W_est): 1.6552e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 25000
# 	h(W_est): 1.7204e-06
# 	score(W_est): 1.1679e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 26000
# 	h(W_est): 1.6650e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 27000
# 	h(W_est): 1.6443e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 28000
# 	h(W_est): 1.8367e-06
# 	score(W_est): 1.1679e+01
# 	obj(W_est): 1.4773e-03
#
# Inner iteration 29000
# 	h(W_est): 1.6980e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 30000
# 	h(W_est): 1.6576e-06
# 	score(W_est): 1.1679e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 31000
# 	h(W_est): 1.8056e-06
# 	score(W_est): 1.1679e+01
# 	obj(W_est): 1.4773e-03
#
# Inner iteration 32000
# 	h(W_est): 1.7421e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4773e-03
#
# Inner iteration 33000
# 	h(W_est): 1.7121e-06
# 	score(W_est): 1.1679e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 34000
# 	h(W_est): 1.7482e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4773e-03
#
# Inner iteration 35000
# 	h(W_est): 1.5208e-06
# 	score(W_est): 1.1681e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 36000
# 	h(W_est): 1.7217e-06
# 	score(W_est): 1.1679e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 37000
# 	h(W_est): 1.6363e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4772e-03
#
# Inner iteration 38000
# 	h(W_est): 1.6763e-06
# 	score(W_est): 1.1680e+01
# 	obj(W_est): 1.4772e-03
# {'fdr': 0.08029197080291971, 'tpr': 0.84, 'fpr': 0.275, 'shd': 32, 'nnz': 137}
