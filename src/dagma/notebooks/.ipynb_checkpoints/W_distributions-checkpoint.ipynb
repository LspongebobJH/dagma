# %% [markdown]
# # preliminary

# %%
import pickle, os
import numpy as np
from numpy.linalg import matrix_power

# %%
root_path = '/Users/jiahang/Documents/dagma/src/dagma/'
n_nodes = 60

# %%
with open(os.path.join(root_path, 'simulated_data/v11/v60/W/W_2_0.pkl'), 'rb') as f:
    W_2_0 = pickle.load(f)
with open(os.path.join(root_path, 'simulated_data/v11/v60/X/X_1.pkl'), 'rb') as f:
    X = pickle.load(f)
    
W = W_2_0['W_est'][:, :n_nodes]
W_true = X['W_true']
B_true = (W_true != 0)
W_est = W_2_0['W_est']

# %%
Z = np.abs(W[:n_nodes, :]) - np.abs(W[n_nodes:, :])
Z0, Z1 = Z[~B_true], Z[B_true]

# %%
# import matplotlib.pyplot as plt
fig, axs = plt.subplots(1, figsize=(10, 4))
axs.hist(X['X'], bins=100, density=True, alpha=0.7)
axs.set_title('X')
# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
X0 = X['X']
max_abs_col = np.abs(X0).max(axis=0).reshape(1, -1)
X1 = X0 / (max_abs_col + 1e-8)

# import matplotlib.pyplot as plt
fig, axs = plt.subplots(1, figsize=(10, 4))
axs.hist(X1, bins=100, density=True, alpha=0.7)
axs.set_title('X1')
# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
np.abs(X1[:, 10]).max()
# Out:
# 0.9999999995627941

# %% [markdown]
# # distributions of knockoff statistics

# %%
# import matplotlib.pyplot as plt
fig, axs = plt.subplots(1, 2, figsize=(10, 4))
axs[0].hist(Z0, bins=100, density=True, alpha=0.7)
axs[0].set_title('Z0')
axs[1].hist(Z1, bins=100, density=True, alpha=0.7)
axs[1].set_title('Z1')
# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
Z_ord.max()
# Out:
# 1.2540541368384213

# %%
Z_ord.min()
# Out:
# -0.3481732028306248

# %%
Z_ord = Z0
Z_ord_name = 'Z0'
print(f'{Z_ord_name} > 5e-3: {(Z_ord > 5e-3).sum() / Z_ord.shape[0] * 100:.2f}%')
print(f'{Z_ord_name} < 5e-3: {(Z_ord < -5e-3).sum() / Z_ord.shape[0] * 100:.2f}%')
# Out:
# Z0 > 5e-3: 17.98%
# Z0 < 5e-3: 2.26%

# %% [markdown]
# # distribution of knockoff statistics of null edges

# %%
W_true_powers = [W_true, matrix_power(W_true, 2), matrix_power(W_true, 3), matrix_power(W_true, 4)]
B_true_powers = [0] + [W != 0 for W in W_true_powers]
W_ori, W_kno = W[:n_nodes, :], W[n_nodes:, :]

# %%
# import matplotlib.pyplot as plt
fig, axs = plt.subplots(1, 4, figsize=(24, 4))

mask = B_true_powers[2] & ~B_true_powers[1] # get cascaded null edges
Z_ord_2 = np.abs(W_ori[mask]) - np.abs(W_kno[mask])
axs[0].hist(Z_ord_2, bins=100, density=True, alpha=0.7)
axs[0].set_title('Z_ord_2')

mask = B_true_powers[3] & ~B_true_powers[1] # get cascaded null edges
Z_ord_3 = np.abs(W_ori[mask]) - np.abs(W_kno[mask])
axs[1].hist(Z_ord_3, bins=100, density=True, alpha=0.7)
axs[1].set_title('Z_ord_3')

mask = B_true_powers[4] & ~B_true_powers[1] # get cascaded null edges
Z_ord_4 = np.abs(W_ori[mask]) - np.abs(W_kno[mask])
axs[2].hist(Z_ord_4, bins=100, density=True, alpha=0.7)
axs[2].set_title('Z_ord_4')

W_true_ord_10 = matrix_power(W_true, 10)
B_true_ord_10 = (W_true_ord_10 != 0)
mask = B_true_ord_10 & ~B_true_powers[1] # get cascaded null edges
Z_ord_10 = np.abs(W_ori[mask]) - np.abs(W_kno[mask])
axs[3].hist(Z_ord_10, bins=100, density=True, alpha=0.7)
axs[3].set_title('Z_ord_10')

# Adjust spacing between subplots
# plt.tight_layout()

# Show the plot
plt.show()

# %%
Z_ord = Z_ord_2
Z_ord_name = 'Z_ord_2'
print(f'{Z_ord_name} > 5e-3: {(Z_ord > 5e-3).sum() / Z_ord.shape[0] * 100:.2f}%')
print(f'{Z_ord_name} < 5e-3: {(Z_ord < -5e-3).sum() / Z_ord.shape[0] * 100:.2f}%')
# Out:
# Z_ord_2 > 5e-3: 32.32%
# Z_ord_2 < 5e-3: 0.25%

# %%
Z_ord = Z_ord_3
Z_ord_name = 'Z_ord_3'
print(f'{Z_ord_name} > 5e-3: {(Z_ord > 5e-3).sum() / Z_ord.shape[0] * 100:.2f}%')
print(f'{Z_ord_name} < 5e-3: {(Z_ord < -5e-3).sum() / Z_ord.shape[0] * 100:.2f}%')
# Out:
# Z_ord_3 > 5e-3: 24.45%
# Z_ord_3 < 5e-3: 1.10%

# %%
Z_ord = Z_ord_4
Z_ord_name = 'Z_ord_4'
print(f'{Z_ord_name} > 5e-3: {(Z_ord > 5e-3).sum() / Z_ord.shape[0] * 100:.2f}%')
print(f'{Z_ord_name} < 5e-3: {(Z_ord < -5e-3).sum() / Z_ord.shape[0] * 100:.2f}%')
# Out:
# Z_ord_4 > 5e-3: 25.84%
# Z_ord_4 < 5e-3: 1.20%

# %%
Z_ord = Z_ord_10
Z_ord_name = 'Z_ord_10'
print(f'{Z_ord_name} > 5e-3: {(Z_ord > 5e-3).sum() / Z_ord.shape[0] * 100:.2f}%')
print(f'{Z_ord_name} < 5e-3: {(Z_ord < -5e-3).sum() / Z_ord.shape[0] * 100:.2f}%')
# Out:
# Z_ord_10 > 5e-3: 23.73%
# Z_ord_10 < 5e-3: 0.00%

# %% [markdown]
# # distribution of knockoff weights

# %%
# import matplotlib.pyplot as plt
fig, axs = plt.subplots(1, 2, figsize=(16, 4))

axs[0].hist(np.abs(W_ori[~B_true]), bins=100, density=True, alpha=0.7)
axs[0].set_title('original null weights')

axs[1].hist(np.abs(W_kno[~B_true]), bins=100, density=True, alpha=0.7)
axs[1].set_title('knockoff null weights')


# Adjust spacing between subplots
# plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # network deconvolution

# %%
from numpy.linalg import eig, eigh, inv, cond

# %%
W_2_0
# Out:
# {'W_est': array([[ 0.00000000e+00, -1.62125406e-04, -6.25173672e-05, ...,
#          -1.67607732e-05, -9.05418578e-06,  5.80096037e-06],
#         [-7.41657509e-05,  0.00000000e+00, -5.13470044e-03, ...,
#           1.92798200e-05, -1.18929818e-05, -9.68079792e-06],
#         [-2.67115947e-05,  4.71654546e-03,  0.00000000e+00, ...,
#          -1.29307435e-05,  7.47957901e-05, -1.77410754e-05],
#         ...,
#         [-1.16044704e-06,  9.70652418e-06, -2.35714104e-06, ...,
#           0.00000000e+00,  7.31910982e-06, -1.37472315e-05],
#         [-1.83800255e-05, -1.58262846e-05, -1.67574019e-06, ...,
#          -3.62855385e-04,  0.00000000e+00, -3.19152707e-05],
#         [ 1.88435808e-01,  1.38613298e-05,  6.16274032e-06, ...,
#           1.82924691e-05, -4.91069405e-06,  0.00000000e+00]]),
#  'Z_true': None,
#  'Z_knock': None}

# %%
W_est = W_2_0['W_est']

# %%
W_est.shape
# Out:
# (120, 120)

# %%
W_est = (W_est + W_est.T) / 2
eigval, eigvec = eigh(W_est)
eigval_p_max, eigval_n_min = eigval[eigval >= 0.].max(), eigval[eigval < 0.].min()

beta = 0.9
m1, m2 = beta / ((1 - beta) * eigval_p_max), -beta / ((1 + beta) * eigval_n_min)
alpha = min(m1, m2)
eigval_dir = eigval / (1 / alpha + eigval)

W_dir = eigvec @ np.diag(eigval_dir) @ eigvec.T

# %%
np.abs(eig(W_dir)[0]).max()
# Out:
# 0.9000000000000015

# %%
W_dir
# Out:
# array([[-7.17277154e-02,  1.03376431e-02,  1.27707560e-02, ...,
#         -1.02331697e-05,  1.02129413e-05,  1.34395708e-02],
#        [ 1.03376431e-02, -4.74328477e-02,  3.12289684e-03, ...,
#          1.13931445e-06, -1.06339937e-06, -8.96229228e-05],
#        [ 1.27707560e-02,  3.12289684e-03, -8.74236092e-02, ...,
#         -2.52769871e-06, -5.70707399e-06, -1.43728443e-04],
#        ...,
#        [-1.02331697e-05,  1.13931445e-06, -2.52769871e-06, ...,
#         -3.96214130e-04,  1.60891995e-06,  8.86278281e-05],
#        [ 1.02129413e-05, -1.06339937e-06, -5.70707399e-06, ...,
#          1.60891995e-06, -5.74501827e-03, -2.68855667e-04],
#        [ 1.34395708e-02, -8.96229228e-05, -1.43728443e-04, ...,
#          8.86278281e-05, -2.68855667e-04, -6.67793772e-04]])

# %%
np.diag(W_dir)
# Out:
# array([-7.17277154e-02, -4.74328477e-02, -8.74236092e-02, -1.13811454e-01,
#        -6.63544659e-02, -7.50742701e-02, -9.14144966e-02, -4.67589368e-02,
#        -1.34916364e-01, -6.08641576e-02, -7.86522631e-02, -6.76213926e-02,
#        -9.14883532e-02, -2.31835294e-02, -5.16304349e-02, -6.04151415e-02,
#        -6.49210327e-02, -8.76345514e-02, -1.26212154e-01, -4.17212110e-02,
#        -6.16944979e-02, -1.34016520e-01, -7.59495149e-02, -5.77576920e-02,
#        -1.12718904e-01, -9.14235812e-02, -1.03584949e-01, -6.38536772e-02,
#        -1.13567165e-01, -5.86949920e-02, -7.12748969e-02, -1.17213805e-01,
#        -7.95329916e-02, -6.84150858e-02, -7.17381246e-02, -1.15551487e-01,
#        -5.43543709e-02, -3.66546645e-02, -5.33574752e-02, -9.70683385e-02,
#        -4.22036030e-02, -4.05671560e-02, -1.46568191e-01, -4.26535957e-02,
#        -7.59643981e-02, -4.92339512e-02, -5.38205597e-02, -5.86155797e-02,
#        -2.82116963e-02, -7.83132282e-02, -7.93183103e-02, -6.81976734e-02,
#        -9.79973905e-02, -5.91246060e-02, -9.64011623e-02, -4.68151408e-02,
#        -6.84302990e-02, -7.94996963e-02, -6.17344906e-02, -1.01852060e-01,
#        -1.19221035e-04, -4.97790181e-06, -5.34719714e-03, -7.52560912e-05,
#        -1.65010581e-07, -4.78058624e-03, -7.48844383e-03, -7.96119391e-04,
#        -2.32288331e-04, -6.79495745e-08, -8.12137350e-06, -7.58372317e-04,
#        -6.51061520e-04, -4.17820659e-03, -1.50606373e-04, -6.36356160e-07,
#        -1.31399590e-03, -2.12903388e-04, -7.28700808e-06, -1.83865655e-04,
#        -8.21155994e-05, -3.70660723e-03, -8.75694869e-05, -3.20641012e-07,
#        -6.09285990e-03, -7.06171663e-04, -7.36235929e-04, -4.82193647e-04,
#        -9.75279719e-03, -1.59832296e-03, -3.57202546e-03, -3.93194022e-03,
#        -6.17247238e-05, -1.54609023e-06, -3.23355571e-06, -8.79871227e-04,
#        -1.04429368e-03, -4.27183171e-04, -8.88526884e-07, -4.13174720e-04,
#        -1.16615229e-04, -3.21359815e-07, -2.33357265e-03, -6.68177509e-03,
#        -9.99394780e-04, -8.32868449e-05, -1.90398437e-04, -1.32800012e-07,
#        -1.01861909e-04, -1.04550618e-03, -2.54068131e-03, -2.82588720e-04,
#        -6.57617939e-03, -7.39860428e-04, -6.96640111e-04, -1.62869556e-03,
#        -5.78530223e-05, -3.96214130e-04, -5.74501827e-03, -6.67793772e-04])

# %%
np.diag(W_dir).sum()
# Out:
# -4.593978748085907

# %%
W_dir_1 = W_dir.copy()

# %%
W_dir_1[np.eye(W_dir_1.shape[0]).astype(bool)] = 0.

# %%
W_dir_1
# Out:
# array([[ 0.00000000e+00,  1.03376431e-02,  1.27707560e-02, ...,
#         -1.02331697e-05,  1.02129413e-05,  1.34395708e-02],
#        [ 1.03376431e-02,  0.00000000e+00,  3.12289684e-03, ...,
#          1.13931445e-06, -1.06339937e-06, -8.96229228e-05],
#        [ 1.27707560e-02,  3.12289684e-03,  0.00000000e+00, ...,
#         -2.52769871e-06, -5.70707399e-06, -1.43728443e-04],
#        ...,
#        [-1.02331697e-05,  1.13931445e-06, -2.52769871e-06, ...,
#          0.00000000e+00,  1.60891995e-06,  8.86278281e-05],
#        [ 1.02129413e-05, -1.06339937e-06, -5.70707399e-06, ...,
#          1.60891995e-06,  0.00000000e+00, -2.68855667e-04],
#        [ 1.34395708e-02, -8.96229228e-05, -1.43728443e-04, ...,
#          8.86278281e-05, -2.68855667e-04,  0.00000000e+00]])

# %%
np.abs(eig(W_dir_1)[0]).max()
# Out:
# 0.8004622365559108
